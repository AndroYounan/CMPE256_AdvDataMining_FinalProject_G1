# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import json
import numpy as np

# Function to load JSON file into Pandas DataFrame
def load_json(filename):
    """Loads a JSON file into a pandas DataFrame"""
    data = []
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    return pd.DataFrame(data)

# Load Yelp dataset
# business_df = load_json(r"C:\BIANCONERI\Master's AI SJSU\5- Advanced Data Mining\Final Project\Yelp-JSON\Yelp JSON\yelp_dataset\yelp_academic_dataset_business.json")
# review_df = load_json(r"C:\BIANCONERI\Master's AI SJSU\5- Advanced Data Mining\Final Project\Yelp-JSON\Yelp JSON\yelp_dataset\yelp_academic_dataset_review.json")
# user_df = load_json(r"C:\BIANCONERI\Master's AI SJSU\5- Advanced Data Mining\Final Project\Yelp-JSON\Yelp JSON\yelp_dataset\yelp_academic_dataset_user.json")
business_df = load_json(r"/home/craig/classwork_2025/CMPE256/FINAL_PROJECT/Yelp-JSON/YelpJSON/yelp_dataset/yelp_academic_dataset_business.json")
review_df = load_json(r"/home/craig/classwork_2025/CMPE256/FINAL_PROJECT/Yelp-JSON/YelpJSON/yelp_dataset/yelp_academic_dataset_review.json")
user_df = load_json(r"/home/craig/classwork_2025/CMPE256/FINAL_PROJECT/Yelp-JSON/YelpJSON/yelp_dataset/yelp_academic_dataset_user.json")
print(f"business_df {business_df.shape}")
print(f"review_df {review_df.shape}")
print(f"user_df {user_df.shape}")

# Filter only OPEN businesses in CALIFORNIA W/ 'categories' column exists and is not null
business_df = business_df[(business_df['state'] == 'CA') & (business_df['is_open'] == 1) & (business_df['categories'].notna())]
print(f"business_df {business_df.shape}")
print(business_df.head())
# Out:
# business_df (150346, 14)
# review_df (6990280, 9)
# user_df (1987897, 22)
# business_df (4064, 14)
#                 business_id                             name  \
# 26   noByYNtDLQAra9ccqxdfDw                              H&M
# 85   IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 91   nUqrF-h9S7myCcvNDecOvw             Iron Horse Auto Body
# 120  bYjnX_J1bHZob10DoSFkqQ      Tinkle Belle Diaper Service
# 141  SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
#
#                    address           city state postal_code   latitude  \
# 26        827-833 State St  Santa Barbara    CA       93101  34.420209
# 85   131 Anacapa St, Ste C  Santa Barbara    CA       93101  34.414445
# 91          825 Cacique St  Santa Barbara    CA       93103  34.419620
# 120                         Santa Barbara    CA       93101  34.420334
# 141      230 Stearns Wharf  Santa Barbara    CA       93101  34.408715
#
#       longitude  stars  review_count  is_open  \
# 26  -119.700460    3.0            24        1
# 85  -119.690672    4.0           389        1
# 91  -119.677032    4.5            32        1
# 120 -119.710749    5.0            17        1
# 141 -119.685019    4.0          2404        1
#
#                                             attributes  \
# 26   {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 85   {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 91   {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 120  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 141  {'OutdoorSeating': 'True', 'RestaurantsAttire'...
#
#                                             categories  \
# 26   Women's Clothing, Accessories, Children's Clot...
# 85   Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 91                      Towing, Automotive, Body Shops
# 120  Parenting Classes, Maternity Wear, Fashion, Ed...
# 141  Live/Raw Food, Restaurants, Seafood, Beer Bar,...
#
#                                                  hours
# 26   {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...
# 85   {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 91   {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...
# 120  {'Monday': '0:0-0:0', 'Tuesday': '10:0-18:0', ...
# 141  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...

# %%
# Extract and print all unique categories from business_df
unique_categories = set()
business_df['categories'].apply(lambda x: unique_categories.update(x.split(', ')))
print(f"Number of unique categories: {len(unique_categories)}")
print(unique_categories)
# Out:
# Number of unique categories: 946
# {'Shopping', 'Tax Services', 'Zoos', 'Surf Schools', 'Diners', 'Officiants', 'Drama Schools', 'Employment Law', 'Rheumatologists', 'Refinishing Services', 'Pets', 'Day Camps', 'Professional Services', 'Skilled Nursing', 'Trusts', 'Gift Shops', 'Allergists', 'Balloon Services', 'Adult Education', 'Homeowner Association', 'Health Coach', 'American (Traditional)', 'Pain Management', 'Tennis', 'Furniture Reupholstery', 'Travel Services', 'Utilities', 'Bubble Tea', 'Gymnastics', 'Emergency Pet Hospital', 'Bed & Breakfast', 'Parenting Classes', 'Art Galleries', 'Car Dealers', 'Trains', 'Mailbox Centers', 'Cinema', 'Brewpubs', 'Gastropubs', 'Cooking Classes', 'Auto Parts & Supplies', 'Art Museums', 'Mobile Dent Repair', 'Pet Sitting', 'Photo Booth Rentals', 'Knife Sharpening', 'Septic Services', 'Screen Printing', 'Tabletop Games', 'Mags', 'Laser Eye Surgery/Lasik', 'Community Service/Non-Profit', 'Web Design', 'Vacation Rental Agents', 'Mobile Phone Accessories', 'Brazilian', 'Shoe Shine', 'Hair Extensions', 'Surgeons', 'Roadside Assistance', 'Event Planning & Services', 'Hair Loss Centers', 'Amusement Parks', 'Laser Hair Removal', 'Nail Salons', 'Test Preparation', 'Art Tours', 'Window Washing', 'Argentine', 'Paddleboarding', 'Hydrotherapy', 'Movers', 'Whale Watching Tours', 'Driving Schools', 'Sandwiches', 'Ranches', 'Business Consulting', 'Pool & Hot Tub Service', 'RV Parks', 'Pulmonologist', 'Moroccan', 'Shopping Centers', 'Scooter Tours', 'Parking', 'Contractors', 'Australian', 'Optometrists', 'Jewelry Repair', 'Fire Protection Services', 'Fish & Chips', 'Thai', 'Commercial Real Estate', 'Childbirth Education', 'Appliances & Repair', 'Estheticians', 'Tattoo Removal', 'Watch Repair', 'Imported Food', 'Snorkeling', 'Ethnic Food', 'Lawn Services', 'Food Stands', 'General Litigation', 'Educational Services', 'Colonics', 'Grilling Equipment', 'Skate Shops', 'Themed Cafes', 'Architectural Tours', 'Bagels', 'Party Equipment Rentals', 'Magicians', 'House Sitters', 'Local Flavor', 'Video/Film Production', 'Trainers', 'Adult', 'Health Markets', 'Dive Bars', 'ATV Rentals/Tours', 'Walk-in Clinics', 'Smog Check Stations', 'Golf Equipment', 'Reflexology', 'Shutters', 'Health & Medical', 'Cosmetics & Beauty Supply', 'Festivals', 'TV Mounting', 'Middle Eastern', 'Immigration Law', 'Food', 'Skate Parks', 'Salvadoran', 'Fences & Gates', 'Trivia Hosts', 'Virtual Reality Centers', 'IT Services & Computer Repair', 'RV Rental', 'Passport & Visa Services', 'Luggage', 'EV Charging Stations', 'Motorcycle Rental', 'Life Coach', 'Framing', 'Medical Spas', 'Swimming Lessons/Schools', 'Orthotics', 'Acne Treatment', 'Advertising', 'Landmarks & Historical Buildings', 'Knitting Supplies', 'Wedding Planning', 'Christmas Trees', 'Electricians', 'Oxygen Bars', 'Gunsmith', 'Vocational & Technical School', 'Jewelry', 'Valet Services', 'Tex-Mex', 'Soup', 'Wine Bars', 'Wildlife Control', 'Supernatural Readings', 'Fitness & Instruction', 'Planetarium', 'Resorts', 'Challenge Courses', 'Nutritionists', 'Kickboxing', 'Home Inspectors', 'Baby Gear & Furniture', 'Packing Supplies', 'Pet Services', 'Watches', 'Pool Cleaners', 'Junk Removal & Hauling', 'Transmission Repair', 'Dermatologists', 'Photographers', 'Gelato', 'Flooring', 'Periodontists', 'Physical Therapy', 'Masonry/Concrete', 'Session Photography', 'Korean', 'Solar Panel Cleaning', 'Counseling & Mental Health', 'Landscaping', 'Tree Services', 'Print Media', 'Radiologists', 'Chicken Wings', 'Jazz & Blues', 'Garage Door Services', 'Halal', 'Delis', 'Scooter Rentals', 'Hunting & Fishing Supplies', 'Lighting Stores', 'Musical Instruments & Teachers', 'Social Clubs', 'Plastic Surgeons', 'Electronics Repair', 'Music Production Services', 'Halotherapy', 'Silent Disco', 'Artificial Turf', 'DJs', 'Vitamins & Supplements', 'Hats', 'Social Security Law', 'Auto Detailing', 'Strip Clubs', 'Vegetarian', 'Pet Photography', 'Orthodontists', 'Discount Store', 'Community Gardens', 'Pilates', 'Donuts', 'Handyman', 'Drugstores', 'Sw ...

# %%
# Convert categories to lowercase for consistency
business_df['categories'] = business_df['categories'].apply(lambda x: [category.lower() for category in x.split(', ')])

# %%
# Define restaurant-related keywords
restaurant_keywords = ["bars","donuts","barbeque", "sandwiches","wineries","fish & chips","vegetarian", "beer", "food", "dessert", "gelato", "restaurants", "wine", "tacos", "tea", "acai bowls", "whiskey", "juice bars & smoothies", "poke", "spirits", "cocktail", "salad", "coffee", "bakeries", "breweries", "pizza", "burgers", "soup", "bagels", "ice cream & frozen yogurt", "ramen", "chicken wings", "food trucks", "cafes", "seafood", "vegan", "diners", "noodles"]

# Filter RESTAURANTS ONLY (businesses with restaurant-related keywords)
restaurants_df = business_df[business_df['categories'].apply(lambda x: any(keyword in x for keyword in restaurant_keywords))]

print(f"restaurants_df {restaurants_df.shape}")

# Select relevant columns // we may get rid of address related columns if we won't use them
restaurants_df = restaurants_df[['business_id', 'name', 'address', 'city', 'postal_code', 'latitude', 'longitude', 'categories', 'stars', 'review_count']]

print(f"restaurants_df {restaurants_df.shape}")
# print(restaurants_df.head())
restaurants_df


# Drop rows with missing values // there is none
#df_clean = restaurants_df.dropna()
#print(f"df_clean {df_clean.shape}")
# Out:
# restaurants_df (1015, 14)
# restaurants_df (1015, 10)
#                    business_id                             name  \
# 85      IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 141     SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 431     ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 470     VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
# 555     bdfZdB2MTXlT6-RBjSIpQg                       Pho Bistro
# ...                        ...                              ...
# 150214  2xxkaRy7rP5EUyjFt2J5kA                      Nikka Ramen
# 150215  8IV78gQwTH-eZgbfFS_plg                Lost & Found Cafe
# 150230  IRBhPAC4ZoDpXazpoB3epQ          Good Stuff Baked Treats
# 150264  Bo-GGwQNcLVwyKeYkbfAYg                      Vino Divino
# 150272  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista
#
#                           address           city postal_code   latitude  \
# 85          131 Anacapa St, Ste C  Santa Barbara       93101  34.414445
# 141             230 Stearns Wharf  Santa Barbara       93101  34.408715
# 431            2733 De La Vina St  Santa Barbara       93105  34.436236
# 470     7320 Hollister Ave, Ste 1         Goleta       93117  34.430542
# 555     903 Embarcadero Del Norte     Isla Vista       93117  34.412934
# ...                           ...            ...         ...        ...
# 150214            5701 Calle Real         Goleta       93117  34.440885
# 150215             919 Linden Ave    Carpinteria       93013  34.398568
# 150230                             Santa Barbara       93101  34.420334
# 150264         2012 De La Vina St  Santa Barbara       93105  34.429154
# 150272    900 Embarcadero Del Mar     Isla Vista       93117  34.412966
#
#          longitude                                         categories  stars  \
# 85     -119.690672  [food, restaurants, salad, coffee & tea, break...    4.0
# 141    -119.685019  [live/raw food, restaurants, seafood, beer bar...    4.0
# 431    -119.726147                               [pizza, restaurants]    4.0
# 470    -119.882367  [burgers, cafes, restaurants, mexican, america...    4.0
# 555    -119.855531  [food, restaurants, chinese, bubble tea, vietn...    3.0
# ...            ...                                                ...    ...
# 150214 -119.823523                     [restaurants, japanese, ramen]    4.5
# 150215 -119.519034  [home decor, home & garden, coffee & tea, food...    5.0
# 150230 -119.710749  [food, food delivery services, bakeries, desse...    5.0
# 150264 -119.717222  [event planning & services, wine tasting room,...    5.0
# 150272 -119.856886  [restaurants, burgers, food, ice cream & froze...    2.5
#
#         review_count
# 85               389
# 141             2404
# 431               64
# 470              189
# 555              184
# ...              ...
# 150214           562
# 150215             5
# 150230             9
# 150264            19
# 150272            12
#
# [1015 rows x 10 columns]

# %%
review_df
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3        kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4        e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
# ...                         ...    ...     ...    ...   ...
# 6990275  jals67o91gcrD4DC81Vk6w    5.0       1      2     1
# 6990276  2vLksaMmSEcGbjI5gywpZA    5.0       2      1     2
# 6990277  R1khUUxidqfaJmcpmGd4aw    4.0       1      0     0
# 6990278  Rr9kKArrMhSLVE9a53q-aA    5.0       1      0     0
# 6990279  VAeEXLbEcI9Emt9KGYq9aA    3.0      10      3     7
#
#                                                       text  \
# 0        If you decide to eat here, just be aware it is...
# 1        I've taken a lot of spin classes over the year...
# 2        Family diner. Had the buffet. Eclectic assortm...
# 3        Wow!  Yummy, different,  delicious.   Our favo...
# 4        Cute interior and owner (?) gave us tour of up...
# ...                                                    ...
# 6990275  Latest addition to services from ICCU is Apple...
# 6990276  This spot offers a great, affordable east week...
# 6990277  This Home Depot won me over when I needed to g...
# 6990278  For when I'm feeling like ignoring my calorie-...
# 6990279  Located in the 'Walking District' in Nashville...
#
#                         date
# 0        2018-07-07 22:09:11
# 1        2012-01-03 15:28:18
# 2        2014-02-05 20:30:30
# 3        2015-01-04 00:01:03
# 4        2017-01-14 20:54:15
# ...                      ...
# 6990275  2014-12-17 21:45:20
# 6990276  2021-03-31 16:55:10
# 6990277  2019-12-30 03:56:30
# 6990278  2022-01-19 18:59:27
# 6990279  2018-01-02 22:50:47
#
# [6990280 rows x 9 columns]

# %%
# Select relevant columns from review_df // I dropped review_id, date, useful, funny, cool
review_df = review_df[['user_id','business_id','stars','text', 'date']]
print(review_df.head())

# Merge reviews with restaurant using business_id as a key
merged_df = review_df.merge(restaurants_df[['business_id', 'name', 'categories']], on='business_id')
print(merged_df.head())
# Out:
#                   user_id             business_id  stars  \
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw    3.0
# 1  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ    5.0
# 2  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A    3.0
# 3  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA    5.0
# 4  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ    4.0
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
#                   user_id             business_id  stars  \
# 0  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg    3.0
# 1  OhECKhQEexFypOMY6kypRw  vC2qm1y3Au5czBtbhc-DNw    4.0
# 2  4hBhtCSgoxkrFgHa4YAD-w  bbEXAEFr4RYHLlZ-HFssTA    5.0
# 3  bFPdtzu11Oi0f92EAcjqmg  IDtLPgUrqorrpqSLdfMhZQ    5.0
# 4  JYYYKt6TdVA4ng9lLcXt_g  SZU9c8V2GuREDN5KgyHFJw    5.0
#
#                                                 text                 date  \
# 0  Had a party of 6 here for hibachi. Our waitres...  2016-07-25 07:31:06
# 1  Yes, this is the only sushi place in town. How...  2013-09-04 03:48:20
# 2  Great burgers,fries and salad!  Burgers have a...  2017-01-02 03:17:34
# 3  What a great addition to the Funk Zone!  Grab ...  2016-10-13 22:50:47
# 4  We were a bit weary about trying the Shellfish...  2016-05-31 02:14:54
#
#                               name  \
# 0  Hibachi Steak House & Sushi Bar
# 1                       Sushi Teri
# 2  The Original Habit Burger Grill
# 3             Helena Avenue Bakery
# 4  Santa Barbara Shellfish Company
#
#                                           categories
# 0   [steakhouses, sushi bars, restaurants, japanese]
# 1                          [restaurants, sushi bars]
# 2                  [fast food, burgers, restaurants]
# 3  [food, restaurants, salad, coffee & tea, break...
# 4  [live/raw food, restaurants, seafood, beer bar...

# %%
# Fix category column if it's a list -> string
merged_df['categories'] = merged_df['categories'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
print(merged_df.head())
# Out:
#                   user_id             business_id  stars  \
# 0  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg    3.0
# 1  OhECKhQEexFypOMY6kypRw  vC2qm1y3Au5czBtbhc-DNw    4.0
# 2  4hBhtCSgoxkrFgHa4YAD-w  bbEXAEFr4RYHLlZ-HFssTA    5.0
# 3  bFPdtzu11Oi0f92EAcjqmg  IDtLPgUrqorrpqSLdfMhZQ    5.0
# 4  JYYYKt6TdVA4ng9lLcXt_g  SZU9c8V2GuREDN5KgyHFJw    5.0
#
#                                                 text                 date  \
# 0  Had a party of 6 here for hibachi. Our waitres...  2016-07-25 07:31:06
# 1  Yes, this is the only sushi place in town. How...  2013-09-04 03:48:20
# 2  Great burgers,fries and salad!  Burgers have a...  2017-01-02 03:17:34
# 3  What a great addition to the Funk Zone!  Grab ...  2016-10-13 22:50:47
# 4  We were a bit weary about trying the Shellfish...  2016-05-31 02:14:54
#
#                               name  \
# 0  Hibachi Steak House & Sushi Bar
# 1                       Sushi Teri
# 2  The Original Habit Burger Grill
# 3             Helena Avenue Bakery
# 4  Santa Barbara Shellfish Company
#
#                                           categories
# 0     steakhouses, sushi bars, restaurants, japanese
# 1                            restaurants, sushi bars
# 2                    fast food, burgers, restaurants
# 3  food, restaurants, salad, coffee & tea, breakf...
# 4  live/raw food, restaurants, seafood, beer bar,...

# %% [markdown]
# # Feature Extraction & Similarity Computation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Feature Extraction for Content-Based Filtering: (TF-IDF) on categories and reviews
tfidf_category = TfidfVectorizer(stop_words='english')
tfidf_review = TfidfVectorizer(stop_words='english')
category_matrix = tfidf_category.fit_transform(merged_df['categories'])
review_matrix = tfidf_review.fit_transform(merged_df['text'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute similarity matrices
category_similarity = cosine_similarity(category_matrix)
review_similarity = cosine_similarity(review_matrix)

# Combine the two similarity matrices into a total similarity matrix by taking their average: 
# Equal weight to both categories and reviews when computing the overall similarity between restaurants.
total_similarity = (category_similarity + review_similarity) / 2
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 4
#       1 from sklearn.metrics.pairwise import cosine_similarity
#       3 # Compute similarity matrices
# ----> 4 category_similarity = cosine_similarity(category_matrix)
#       5 review_similarity = cosine_similarity(review_matrix)
#       7 # Combine the two similarity matrices into a total similarity matrix by taking their average:
#       8 # Equal weight to both categories and reviews when computing the overall similarity between restaurants.
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1687, in cosine_similarity(X, Y, dense_output)
#    1684 else:
#    1685     Y_normalized = normalize(Y, copy=True)
# -> 1687 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1689 return K
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/extmath.py:205, in safe_sparse_dot(a, b, dense_output)
#     203         ret = np.dot(a, b)
#     204 else:
# --> 205     ret = a @ b
#     207 if (
#     208     sparse.issparse(a)
#     209     and sparse.issparse(b)
#     210     and dense_output
#     211     and hasattr(ret, "toarray")
#     212 ):
#     213     return ret.toarray()
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/_base.py:669, in _spbase.__matmul__(self, other)
#     666 if isscalarlike(other):
#     667     raise ValueError("Scalar operands are not allowed, "
#     668                      "use '*' instead")
# --> 669 return self._matmul_dispatch(other)
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/_base.py:580, in _spbase._matmul_dispatch(self, other)
#     578     if self.shape[-1] != other.shape[0]:
#     579         raise ValueError('dimension mismatch')
# --> 580     return self._matmul_sparse(other)
#     582 # If it's a list or whatever, treat it like an array
#     583 other_a = np.asanyarray(other)
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/_compressed.py:550, in _cs_matrix._matmul_sparse(self, other)
#     545 idx_dtype = self._get_index_dtype((self.indptr, self.indices,
#     546                              other.indptr, other.indices),
#     547                             maxval=nnz)
#     549 indptr = np.empty(major_dim + 1, dtype=idx_dtype)
# --> 550 indices = np.empty(nnz, dtype=idx_dtype)
#     551 data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     553 fn = getattr(_sparsetools, self.format + '_matmat')
#
# MemoryError: Unable to allocate 242. GiB for an array with shape (32478999457,) and data type int64

# %%
from sklearn.neighbors import NearestNeighbors

# Switched to use NearestNeighbors for memory-efficient similarity computation
category_nn = NearestNeighbors(metric='cosine').fit(category_matrix)
review_nn = NearestNeighbors(metric='cosine').fit(review_matrix)

# %% [markdown]
# # Collaborative Filtering

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# Split the data into train nd test sets (80,20 split)
train_data, test_data = train_test_split(merged_df, test_size=0.2, random_state=42)

# User-Restaurant interaction matrix for Collaborative Filtering using 'stars'
user_restaurant_matrix = train_data.pivot_table(index='user_id', columns='business_id', values='stars', fill_value=0)
print(user_restaurant_matrix.head())

# Calculate the total number of elements in the matrix
total_elements = user_restaurant_matrix.size
# Calculate the number of non-zero elements
non_zero_elements = (user_restaurant_matrix != 0).sum().sum()
# Calculate density
density = non_zero_elements / total_elements
# Calculate sparsity
sparsity = 1 - density
print(f"Total Elements: {total_elements}")
print(f"Non-Zero Elements: {non_zero_elements}")
print(f"Density: {density:.4f}")
print(f"Sparsity: {sparsity:.4f}")

# Compute user similarity matrix
user_similarity = cosine_similarity(user_restaurant_matrix)
print(user_similarity)

# %%
# Filter users with at least 5 ratings to save on memory
user_counts = train_data['user_id'].value_counts()
filtered_df = train_data[train_data['user_id'].isin(user_counts[user_counts >= 5].index)]

# Filter restaurants with at least 5 ratings
item_counts = filtered_df['business_id'].value_counts()
filtered_df = filtered_df[filtered_df['business_id'].isin(item_counts[item_counts >= 5].index)]

# Recompute User-Restaurant interaction matrix using filtered_df
user_restaurant_matrix = filtered_df.pivot_table(index='user_id', columns='business_id', values='stars', fill_value=0)
print(user_restaurant_matrix.head())

# Calculate the total number of elements in the matrix
total_elements = user_restaurant_matrix.size
# Calculate the number of non-zero elements
non_zero_elements = (user_restaurant_matrix != 0).sum().sum()
# Calculate density
density = non_zero_elements / total_elements
# Calculate sparsity
sparsity = 1 - density
print(f"Total Elements: {total_elements}")
print(f"Non-Zero Elements: {non_zero_elements}")
print(f"Density: {density:.4f}")
print(f"Sparsity: {sparsity:.4f}")

# Recompute user similarity matrix
user_similarity = cosine_similarity(user_restaurant_matrix)
print(user_similarity)

# %%
def get_cf_recommendations(user_id, user_similarity, user_restaurant_matrix, merged_df, top_n=5):
    """
    Generate restaurant recommendations for a user using collaborative filtering.
    
    Args:
        user_id (str): The ID of the user for whom recommendations are generated.
        user_similarity (numpy array): User similarity matrix.
        user_restaurant_matrix (DataFrame): User-restaurant interaction matrix.
        merged_df (DataFrame): The original DataFrame containing restaurant names.
        top_n (int): Number of recommendations to return.
    
    Returns:
        list: List of recommended restaurant IDs.
    """
    # Get the index of the user in the user-item matrix
    user_index = user_restaurant_matrix.index.get_loc(user_id)
    
    # Get the similarity scores for the user
    user_sim_scores = user_similarity[user_index]
    
    # Get the indices of the most similar users (excluding the user themselves)
    similar_users_indices = user_sim_scores.argsort()[::-1][1:top_n + 1]
    
    # Get the restaurants rated by similar users
    recommended_restaurants = set()
    for sim_user_index in similar_users_indices:
        sim_user_id = user_restaurant_matrix.index[sim_user_index]
        # Get restaurants rated highly by the similar user
        sim_user_ratings = user_restaurant_matrix.loc[sim_user_id]
        highly_rated_restaurants = sim_user_ratings[sim_user_ratings >= 4].index  # Restaurants rated 4 or 5 stars ONLY
        recommended_restaurants.update(highly_rated_restaurants)
    
    # Exclude restaurants already rated by the user
    user_rated_restaurants = user_restaurant_matrix.loc[user_id][user_restaurant_matrix.loc[user_id] > 0].index
    recommended_restaurants = recommended_restaurants - set(user_rated_restaurants)
    
    # Get the names & categories of the recommended restaurants
    recommended_restaurant_names = merged_df[merged_df['business_id'].isin(recommended_restaurants)]['name'].unique()
    print(list(recommended_restaurant_names)[:top_n])
    recommended_restaurant_categories = merged_df[merged_df['business_id'].isin(recommended_restaurants)]['categories'].unique()
    print(list(recommended_restaurant_categories)[:top_n])

    return list(recommended_restaurants)[:top_n]

# %%
# Example: Get CF recommendations for a specific user
user_id = '-0-TtVhV4PIUoDpUCOC0uQ'
recommendations = get_cf_recommendations(user_id, user_similarity, user_restaurant_matrix, merged_df, top_n=5)
print("Recommended Restaurants:", recommendations)

# %% [markdown]
# ## experiments other similarities

# %%
# CF filtering (cosine)

# Filter users with at least 5 ratings to save on memory
user_counts = train_data['user_id'].value_counts()
filtered_df = train_data[train_data['user_id'].isin(user_counts[user_counts >= 5].index)]

# Filter restaurants with at least 5 ratings
item_counts = filtered_df['business_id'].value_counts()
filtered_df = filtered_df[filtered_df['business_id'].isin(item_counts[item_counts >= 5].index)]

# Recompute User-Restaurant interaction matrix using filtered_df
train_user_restaurant_matrix = filtered_df.pivot_table(index='user_id', columns='business_id', values='stars', fill_value=0)

# Fill missing values with 0 (indicating no rating for that business)
train_user_restaurant_matrix = train_user_restaurant_matrix.fillna(0)

# %%
from sklearn.metrics.pairwise import cosine_similarity

train_user_similarity = cosine_similarity(train_user_restaurant_matrix)

train_user_similarity_df = pd.DataFrame(train_user_similarity, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

# %%
def recommend_businesses(user_id, user_similarity_df, user_item_matrix, num_recommendations=5):
    if user_id not in user_similarity_df.index:
        print("not enough info for user")
        return user_item_matrix.mean(axis=0).sort_values(ascending=False).head(num_recommendations).index
    
    similar_users = user_similarity_df[user_id].sort_values(ascending=False).index[1:num_recommendations+1]
    
    similar_users_ratings = user_item_matrix.loc[similar_users]
    
    #should normalize the ratings first?
    recommended_businesses = similar_users_ratings.sum(axis=0).sort_values(ascending=False)
    
    recommended_businesses = recommended_businesses[user_item_matrix.loc[user_id] == 0].head(num_recommendations)
    
    return recommended_businesses.index

# Test on specific user
recommended_restaurants = recommend_businesses(user_id='-0-TtVhV4PIUoDpUCOC0uQ', user_similarity_df=train_user_similarity_df, user_item_matrix=train_user_restaurant_matrix)

names = merged_df[merged_df['business_id'].isin(recommended_restaurants)]['name'].unique()
print(names)
# Out:
# ['Poke Theory SB' "Woodstock's Pizza Isla Vista" 'Los Agaves'
#  'TAP Thai Cuisine' "Andersen's Danish Bakery & Restaurant"]

# %%
## content based filtering (cosine)

# Preprocess categories column (split categories into separate columns)

business_df['categories'] = business_df['categories'].apply(lambda x: ', '.join(x) if isinstance(x, list) else '')

from sklearn.feature_extraction.text import TfidfVectorizer

business_df.reset_index(inplace=True)

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(business_df['categories'])

# %%
# Calculate business similarity based on their categories
business_similarity = cosine_similarity(tfidf_matrix)

# Convert to DataFrame for easier interpretation
# business_similarity_df = pd.DataFrame(business_similarity, index=business_df['business_id'], columns=business_df['business_id'])

# %%
# I don't think this is working

def recommend_businesses_content(user_id, business_similarity_df, user_item_matrix, num_recommendations=5):
    rated_businesses = user_item_matrix.loc[user_id][user_item_matrix.loc[user_id] >= 4].index

    similar_scores = business_similarity_df.loc[rated_businesses].mean(axis=0)  # Mean similarity score across rated businesses

    similar_scores = similar_scores.sort_values(ascending=False)

    recommended_businesses = similar_scores[~similar_scores.index.isin(rated_businesses)]

    recommended_businesses = recommended_businesses.head(num_recommendations)
    
    return recommended_businesses.index

recommended_restaurants = recommend_businesses_content(user_id='-0-TtVhV4PIUoDpUCOC0uQ', business_similarity_df=business_similarity_df, user_item_matrix=user_restaurant_matrix)
names = merged_df[merged_df['business_id'].isin(recommended_restaurants)]['name'].unique()
print(names)
# Out:
# ['KFC' 'Your Choice' "Kyle's Kitchen" 'Hochaya']

# %%
def recommend_businesses(business_id, cosine_sim, num_recommendations=5):
    idx = business_df[business_df['business_id'] == business_id].index[0]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    sim_scores = sim_scores[1:num_recommendations+1]
    
    business_indices = [i[0] for i in sim_scores]
    
    return business_df.iloc[business_indices][['business_id', 'name', 'categories']]

recommend_businesses(business_id='P_QAD4_iMgqTaWd5On_n3g', cosine_sim=business_similarity)
# names = merged_df[merged_df['business_id'].isin(recommended_restaurants)]['name'].unique()
# print(names)
# Out:
#                  business_id                           name  \
# 3125  bPVPZeqMuYtU_yGCb4P-jg  Empty Bowl Gourmet Noodle Bar
# 359   I0jFTYVDs-WHwKR2XHQlRA           Zen Yai Thai Cuisine
# 3201  Xw_5QkLTyIEg6Hs-kXGNbg        Galanga Thai Restaurant
# 684   cZ6sHHLv7VSmuFSxP6sQLg                       Lao Wang
# 16    18eWJFJbXyR9j_5xfcRLYA                  Siam Elephant
#
#                                              categories
# 3125  comfort food, asian fusion, chinese, tapas/sma...
# 359   thai, restaurants, american (new), pop-up rest...
# 3201                   soup, thai, restaurants, noodles
# 684   noodles, restaurants, gluten-free, creperies, ...
# 16                                    restaurants, thai

# %% [markdown]
# # Experiments metrics for CF

# %%
# process train df
# Filter users with at least 5 ratings to save on memory
user_counts = test_data['user_id'].value_counts()
test_filtered_df = test_data[test_data['user_id'].isin(user_counts[user_counts >= 5].index)]

# Filter restaurants with at least 5 ratings
item_counts = test_filtered_df['business_id'].value_counts()
test_filtered_df = test_filtered_df[test_filtered_df['business_id'].isin(item_counts[item_counts >= 5].index)]

# Recompute User-Restaurant interaction matrix using filtered_df
test_user_restaurant_matrix = test_filtered_df.pivot_table(index='user_id', columns='business_id', values='stars', fill_value=0)

# Fill missing values with 0 (indicating no rating for that business)
test_user_restaurant_matrix = test_user_restaurant_matrix.fillna(0)

# %%
test_user_similarity = cosine_similarity(test_user_restaurant_matrix)

test_user_similarity_df = pd.DataFrame(test_user_similarity, index=test_user_restaurant_matrix.index, columns=test_user_restaurant_matrix.index)

# %%
recommendations = {}
for user_id in test_user_restaurant_matrix.index:
    recs = recommend_businesses(user_id=user_id, user_similarity_df=train_user_similarity_df, user_item_matrix=train_user_restaurant_matrix)
    recommendations[user_id] = recs
# Out:
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user

# %%
recommendations
# Out:
# {'-1WbN1Qd-opw8u3uEqs2Kg': Index(['cnG65HES0L_jCgbrWKtnVg', 'EPkF-beh6gg_s3HtlAdfiw',
#         '5Z7HXqp22lSiN0Q8iF94hQ', '7iQ93RWLLYOa7QRMcHgEtA',
#         'WhTRPUduXy3mRBYlmSmsKw'],
#        dtype='object', name='business_id'),
#  '-7Eh_8y1ihj3nNtdIetiRA': Index(['qUH2FppY7RL96F5tXzA0hQ', 'bA0vBB4ztXjzM4SVA8balQ',
#         'O3jPfTDRn5_1O3ZM_LuxQw', '1oGCzoCC6HnQWpdK9cCP0g',
#         'AGtZA_0tR0erViKGTCGtQg'],
#        dtype='object', name='business_id'),
#  '-B-QEUESGWHPE_889WJaeg': Index(['bXrQejeR66IwebuhxPS7GA', 'qM2gfO-cqpDzxmIX-XzuWA',
#         'edJoBsse6nsF0BYh6pATAg', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'iBTc6XKgW5HESEZIii-G4g'],
#        dtype='object', name='business_id'),
#  '-BB9oz-WY-H2oBazb4Ltzw': Index(['Rl42JbSMsmNW3LRjsTMYAg', 'LlGIlNJE2Nv_PXkH7l4Wmg',
#         'CYwC5OjwCN6ib_AQDxi3Ow', '5Z7HXqp22lSiN0Q8iF94hQ',
#         'edJoBsse6nsF0BYh6pATAg'],
#        dtype='object', name='business_id'),
#  '-Oqfoc4KyhzYY0qvSkxkrg': Index(['BttSAciQNIQhgJCv3-FYpw', '5vObJIHLO-QOMrw_MvC4rA',
#         'wJiaLWAxfqDeFsmE2cI8tg', '_ecVi-tVoaKHKYxNkxFj7w',
#         'UjgqSqa4Biy34pHSEdwj_g'],
#        dtype='object', name='business_id'),
#  '04z9-h0s1EewybGNxULh3w': Index(['WrU1ZYN4jlYcL5mvJrQsCQ', 'thlyktt2c7v1DyOpSVSibw',
#         'znlrxrY4InSx7ekPZxoHRw', 'AmAc0eD6lyVyb7QdOAO1Mg',
#         'eL4lyE7LNoXEMvpcJ8WNVw'],
#        dtype='object', name='business_id'),
#  '0KQf-Ojt6Dx-r_izRHt3qw': Index(['CoZ2mpsMBP8HUG1ymKoZTg', 'syuKX2pH3JJhOOppzNI6SA',
#         'r2IhvKZQ_wLR5mLBnPOilg', '-FM4CxOg4XXmX_Ebky_SiQ',
#         'oGDGlUbOjHxmmCh8ZYcDCg'],
#        dtype='object', name='business_id'),
#  '0oB6T_30B8oOHDhSuiXFqg': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         '3VrqxApK-iwfRohlAuIt0g', 'NIQWO-Q_F598XlAvZnFVCA',
#         'Rl42JbSMsmNW3LRjsTMYAg'],
#        dtype='object', name='business_id'),
#  '0sCoAM1rwTrA7Co9WdOPWQ': Index(['wFES5bGDiPANW13hNHnXOQ', 'JSrab1rTrhBq0X80o6fPrQ',
#         '6EizP0XyqITuGZ8GZMI9Lw', 'vhWlxyLEWAbNOMtQ42yzFg',
#         'y4x_wAQvUxvTR8iV-JP4Jg'],
#        dtype='object', name='business_id'),
#  '0tJNWu6aICRiUcHEczHQpw': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  '0xOCffHgZXEjMZ-3dj7yEg': Index(['uZYBF0YTU_iKq4_L_PDtMQ', 'm4kvY0viCwxqRtgOycnKVQ',
#         'wb9P0ipW4ysbgNA9jIl3bg', 'iHdrLu8deF5GceB0V1rPhA',
#         'YXaCcpETNtxrNNK6TbUTlw'],
#        dtype='object', name='business_id'),
#  '13rOi3iY3AUftebDxEWgRw': Index(['UuRZpgZsHX7PyykHV3wbZg', 'Qkg16mN-8QR66gjzg6gMyw',
#         'BVzFvRrgMpL62oPIqGvLMg', 'wupvqueqdEZXQxv14sa9vw',
#         'RRGLss4hhvZZuR0N6GQlSw'],
#        dtype='object', name='business_id'),
#  '1Epz9OPDXb8Hwrl7vXK1oQ': Index(['fqStx0SvwMFChX_HIdUeEQ', 'JSrab1rTrhBq0X80o6fPrQ',
#         '6EizP0XyqITuGZ8GZMI9Lw', 'IDtLPgUrqorrpqSLdfMhZQ',
#         'JpwG8sDNsHuD0f6NF6YuGw'],
#        dtype='object', name='business_id'),
#  '1SFWznILNfVjYMsQ7GvlDg': Index(['9ugpNKKhnYRa51qXoxUw_A', 'BEzvmorW8ILha6tcSxBBwA',
#         'BErYojCJSO959vzaz9JclQ', 'BaWVwChTW_MqkKru_WZp3g',
#         'L6nIOUwcTGgQKExGHmvTzQ'],
#        dtype='object', name='business_id'),
#  '1XLiW-xgvoD8RgVBdKzn2w': Index(['0ac5lGA_0wdKDnib3y59Xg', 'CkENBnSJFfPA1hY0qrqfCg',
#         'IZZ7J14VnJGyUqYH1tgT6w', 'GuzbBFraIq-fbkjfvaTRvg',
#         'edJoBsse6nsF0BYh6pATAg'],
#        dtype='object', name='business_id'),
#  '1eUlRRmm0DLkq1eo0ro6Hw': Index(['6EizP0XyqITuGZ8GZMI9Lw', 'zbrIMldF_O1ZQ0vpUaaa8A',
#         'B1yPXzIIJrLWyTcE4jsYuQ', 'GuzbBFraIq-fbkjfvaTRvg',
#         'q-1ICFSqs2MwDGfe5tX-SQ'],
#        dtype='object', name='business_id'),
#  '1l9p01i_mCPtCviUg7aUkQ': Index(['FH0MVF7kK0D76Hh4e7hXfQ', '0it-2gWk_gyuZyEMQzBBuQ',
#         'BErYojCJSO959vzaz9JclQ', 'fqStx0SvwMFChX_HIdUeEQ',
#         '0qu0fNTOsSmuREYVIMPuIQ'],
#        dtype='object', name='business_id'),
#  '1orfwtwIaqCbLgfs3W1i6Q': Index(['r926yelr_EJAKQCjdD6AWA', 'CoZ2mpsMBP8HUG1ymKoZTg',
#         'iMTjejk6apJKzCukZnDw5A', 'CziOtnFSklimJnBgksDDwA',
#         '-3AooxIkg38UyUdlz5oXdw'],
#        dtype='object', name='business_id'),
#  '1xMo3tOIW1s9J1VhwES20A': Index(['B2Mpi0gW4-oFFVKkDpIxvg', '8MoqZqlNN9AXzG91_Hpc_Q',
#         'sor6oj-nuslOcSx7di4urA', 'TVX2a4bVuCE2VUIkiLdZrQ',
#         '9ugpNKKhnYRa51qXoxUw_A'],
#        dtype='object', name='business_id'),
#  '27hyqoJVv66JN_Z8pduSBA': Index(['4D7QDfPOsSPfKxBi3gs_qQ', '6RBZfirnzE4NahJTn1UPNA',
#         '9ugpNKKhnYRa51qXoxUw_A', '2xxkaRy7rP5EUyjFt2J5kA',
#         'BQv7ntaOxs80FJAji2U9pg'],
#        dtype='object', name='business_id'),
#  '29snpxOsSJtFbcgmMIX1FA': Index(['SZU9c8V2GuREDN5KgyHFJw', 'U3grYFIeu6RgAAQgdriHww',
#         '9ugpNKKhnYRa51qXoxUw_A', 'q-1ICFSqs2MwDGfe5tX-SQ',
#         'Xw_5QkLTyIEg6Hs-kXGNbg'],
#        dtype='object', name='business_id'),
#  '2PeqtdiehYm82TXymQUGow': Index(['uO39--k_hrCFgZh-Bl8m8A', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'f4aCur7Vrf9F8YUAOFFWiA', 'COSC9JC0Vjr89CaTZuPkUA',
#         'bLnC1_-Kd_Z5qhHNQXCUfQ'],
#        dtype='object', name='business_id'),
#  '2YcV4Ez46mBItRIehYeoGA': Index(['3xJ_6qxRA0sdUm3ThCPiCw', 'zbrIMldF_O1ZQ0vpUaaa8A',
#         'VZhRxX3BzU09qK4UlXrN4g', '0it-2gWk_gyuZyEMQzBBuQ',
#         'cOoTIQ0RcudE1R5aRVZzdw'],
#        dtype='object', name='business_id'),
#  '2ZpI58gpkhK_c3nf4PvPfQ': Index(['FpNhzu3w0XgyedhOLDuK8g', 'bSfDI69RkUrodsA1QwgnOg',
#         'r926yelr_EJAKQCjdD6AWA', 'uPaVoR6XHk12KT9KTr1WFw',
#         '2N9WHETHcYJsfYpHQ-qN_A'],
#        dtype='object', name='business_id'),
#  '2_PLbxySxatOJDlEMFghGw': Index(['-3AooxIkg38UyUdlz5oXdw', 'W7gSJz80DywKnPRIGjA2Bw',
#         'b2Za53CjptGyf9K0fFnrAg', 'wK2IixmZUOEFGz1QZqR99Q',
#         'BErYojCJSO959vzaz9JclQ'],
#        dtype='object', name='business_id'),
#  '2gas35gMf50hdkVeUxYQQg': Index(['skY6r8WAkYqpV7_TxNm23w', 'MbzgGsMQpGyVrUJXi_Jw0Q',
#         'edJoBsse6nsF0BYh6pATAg', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         'oGDGlUbOjHxmmCh8ZYcDCg'],
#        dtype='object', name='business_id'),
#  '2lcbrCNM4nv189NiRw1vgw': Index(['znlrxrY4InSx7ekPZxoHRw', 'NIQWO-Q_F598XlAvZnFVCA',
#         'XkmJfBmH-G7eLiq8vJnJRQ', '0qu0fNTOsSmuREYVIMPuIQ',
#         'Rl42JbSMsmNW3LRjsTMYAg'],
#        dtype='object', name='business_id'),
#  '2uGGrCtfoAju9tdj5RHEpw': Index(['yPSejq3_erxo9zdVYTBnZA', 'v1Uesklh8DpEufYOhTq4iA',
#         'Hl_vXTiYLozWo7T9Cq17vw', 'uO39--k_hrCFgZh-Bl8m8A',
#         'B_q2xoAgTyn6U4YNEc3kSw'],
#        dtype='object', name='business_id'),
#  '32bzjxbJCYM61y6sbA7rxA': Index(['tf6S06LD09IFDHUpOPqPaw', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'YrNtBUOUOYwmRZ_UVwH8iQ', 'yPSejq3_erxo9zdVYTBnZA',
#         'fVUurZgbWXzp2QzDzJzmpA'],
#        dtype='object', name='business_id'),
#  '3XzhO2aJdvVtYhKOCJsPrg': Index(['b1shfPbHpkeWtbGbz5iAtg', 'eikRexw04kC6siBDkFnayQ',
#         'c0p9TawJSQHchy5aL8NWgQ', 'XgehM3pBZWuXi45J2dqRJQ',
#         'j2JyjUtiSeZ7v47stnyR7w'],
#        dtype='object', name='business_id'),
#  '3jzlGVKBwsRo0snmyUonWw': Index(['_ecVi-tVoaKHKYxNkxFj7w', 'vhWlxyLEWAbNOMtQ42yzFg',
#         'vyOVT4bcW227LRwJGHTeSw', '2xxkaRy7rP5EUyjFt2J5kA',
#         'p2kC-cD22QAQzIGD8ZuqFA'],
#        dtype='object', name='business_id'),
#  '3wrP0tYDhaXjrIrQjeTf_Q': Index(['bPVPZeqMuYtU_yGCb4P-jg', '7IdIGemGZodDAA_9mJCigA',
#         'TzNk1TcWLZn0JCpO83hBAA', 'CWdCNIJU4Kh480NV9dgQjw',
#         'AV3XPH1iv8PKSO6mrnYgLg'],
#        dtype='object', name='business_id'),
#  '41m9Kp_HCztXMr_Fx7eKQw': Index(['U3grYFIeu6RgAAQgdriHww', 'LKM0wL3GMsi8NwEdz-_n8w',
#         'WhTRPUduXy3mRBYlmSmsKw', '8_r9EZL6vX5fPBoVh3gUrA',
#         'yPSejq3_erxo9zdVYTBnZA'],
#        dtype='object', name='business_id'),
#  '46nD6kcP-KZXsEyfP0etmQ': Index(['bbEXAEFr4RYHLlZ-HFssTA', '8Vo6LN9gqULhXzoxj5k6kQ',
#         '8A5LSwsKK5vXDH1M3_Tf1w', 'lZ44dxn1TCzJaVBa8Ze8DQ',
#         'I0jFTYVDs-WHwKR2XHQlRA'],
#        dtype='object', name='business_id'),
#  '4DyMRBKrokax6d8LCI3GAw': Index(['-TjT3y-Glfnbt6LbKETAYg', 'oGDGlUbOjHxmmCh8ZYcDCg',
#         'eikRexw04kC6siBDkFnayQ', 'SZU9c8V2GuREDN5KgyHFJw',
#         'eL4lyE7LNoXEMvpcJ8WNVw'],
#        dtype='object', name='business_id'),
#  '4HMjyMaBEkiS2y7QbbGF9w': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  '4TpuhZYMTmVqSaXKliavrA': Index(['2nk4hq2oRfym8ROQ5iS47g', 'O2lFAWD2WXXx5EKkzPutWQ',
#         '8Vo6LN9gqULhXzoxj5k6kQ', '6HTGlttrzCMsuGBHO1ZGiw',
#         'wxdpQV7CZHn6_DFr-JGUgw'],
#        dtype='object', name='business_id'),
#  '4ZaqBJqt7laPPs8xfWvr6A': Index(['U3grYFIeu6RgAAQgdriHww', 'c0p9TawJSQHchy5aL8NWgQ',
#         'OCW1gs6Rjn90_x5EV0PuaA', 'edJoBsse6nsF0BYh6pATAg',
#         'v4lz71o76wWD8H15NsbZGA'],
#        dtype='object', name='business_id'),
#  '4hX_SM38SC7yDh4qCmBVlw': Index(['WhTRPUduXy3mRBYlmSmsKw', '6EizP0XyqITuGZ8GZMI9Lw',
#         'qM2gfO-cqpDzxmIX-XzuWA', 'RRGLss4hhvZZuR0N6GQlSw',
#         '2N9WHETHcYJsfYpHQ-qN_A'],
#        dtype='object', name='business_id'),
#  '4jXXxK5cljqbnDlPGuMnsQ': Index(['PWWGbkPC_agn-4s1Hv1W5A', 'Nbht3URjeV94507do0goEw',
#         '-kY_HDP7IMvGl-kBIZVU4A', 'ghLjxj4HoSHdflBEz2lIqA',
#         'Kthnb7PjDSd7FsBp4wqoHA'],
#        dtype='object', name='business_id'),
#  '4qLX3RyxJC8Y47z6Xd_erQ': Index(['DqVpNtgFCP47n6frh-LREA', 'k3lTRgvPvYUI-cX7_TAqNA',
#         'mPKqBWLSD8wxJLJ_4juY2w', 'ghLjxj4HoSHdflBEz2lIqA',
#         '5RsVAkDnMrcSbErS6P1eew'],
#        dtype='object', name='business_id'),
#  '51ECdjkXs7ZJcleB2VyqSQ': Index(['oGDGlUbOjHxmmCh8ZYcDCg', 'NTLvzcGNm4IUF_yXIwIhvA',
#         'yPSejq3_erxo9zdVYTBnZA', 'iBBV8vesQ8fo2IQA7an1JA',
#         'qdpdUjdkEUpzYDdce2yZng'],
#        dtype='object', name='business_id'),
#  '55SuBikniNRwz4qdF7vLUQ': Index(['Rl42JbSMsmNW3LRjsTMYAg', 'EPkF-beh6gg_s3HtlAdfiw',
#         'ifjluUv4VASwmFqEp8cWlQ', 'tyt3pz0x3ZB8GXsSx1a9Aw',
#         '8vMULlBjFJyS_836tOKnVQ'],
#        dtype='object', name='business_id'),
#  '58zhqwfGYEl92MZusTsYJg': Index(['mPKqBWLSD8wxJLJ_4juY2w', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         '06pNHtxgPhGhZpM0Z2uzNw', 'znlrxrY4InSx7ekPZxoHRw',
#         'BErYojCJSO959vzaz9JclQ'],
#        dtype='object', name='business_id'),
#  '5BpJEC8YVi80ecWT5CtlfQ': Index(['E_ac8Q20OJD9L8cafCBKaQ', '-TjT3y-Glfnbt6LbKETAYg',
#         'skY6r8WAkYqpV7_TxNm23w', 'VAIOtbsxdNmuhUKkQZFRlA',
#         'zbrIMldF_O1ZQ0vpUaaa8A'],
#        dtype='object', name='business_id'),
#  '5FgWswuxsksmQnUFP1OtVg': Index(['2l-spLLGUzRiZg8dF623Nw', 'f3eve2cxUIzyanWnHdMtFQ',
#         'YrNtBUOUOYwmRZ_UVwH8iQ', 'o9dB3ptlB9qdiOvJzMeSLw',
#         'AzZqXglv_puXwd4kCvM7ew'],
#        dtype='object', name='business_id'),
#  '5MOocjdb0_R2HfLXdgbLaA': Index(['FdoqtMadj4ybDAL7S-yUBQ', 'bbEXAEFr4RYHLlZ-HFssTA',
#         'iHdrLu8deF5GceB0V1rPhA', 'SsHMgOW3TT48Z7jeV5beqQ',
#         '-loV4cB2Uh9TCltTRgGzWQ'],
#        dtype='object', name='business_id'),
#  '5YuyrlbXuUdG9r2vcAzbLw': Index(['FpNhzu3w0XgyedhOLDuK8g', 'C6AiAF35zwpAoK5jjm-nhA',
#         'UA3HxLprLSOO9J6l1iR2Cg', 'xkS_mRHVHuX0ko6kVIyBdA',
#         '9kfN12wVGnKo54AaRjz0vQ'],
#        dtype='object', name='business_id'),
#  '5e7Kg-X_K3tnePHKa63pdA': Index(['2xxkaRy7rP5EUyjFt2J5kA', 'syuKX2pH3JJhOOppzNI6SA',
#         '27zlxlmlQu9KBr5Vj4MGeg', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'vmq2cm0Ayol4toVsL4dZfA'],
#        dtype='object', name='business_id'),
#  '5mma9y-FhPvL6AI8hqcgzQ': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  '5xw0gXAcuX_BVcMd4V3XOA': Index(['JSrab1rTrhBq0X80o6fPrQ', 'skY6r8WAkYqpV7_TxNm23w',
#         '6HTGlttrzCMsuGBHO1ZGiw', 'GuzbBFraIq-fbkjfvaTRvg',
#         'znlrxrY4InSx7ekPZxoHRw'],
#        dtype='object', name='business_id'),
#  '61yERKmEa_0mkZYy_3PNAg': Index(['m4kvY0viCwxqRtgOycnKVQ', '-FM4CxOg4XXmX_Ebky_SiQ',
#         'iBTc6XKgW5HESEZIii-G4g', 'bf32KWp9yvN-WT8c-QtbzA',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  '66SCo2UIwTW8U_O893Eu4Q': Index(['U3grYFIeu6RgAAQgdriHww', 'AGtZA_0tR0erViKGTCGtQg',
#         '2YnQAJdeFrcgPa8MqIYcDg', 'crlk8kaurC4zrPUTt7BevQ',
#         'IZJacI6XEUxy3_wbW76Qfw'],
#        dtype='object', name='business_id'),
#  '6BZMGaiBMQSZ639VfjbVaA': Index(['34Eqv8jXgxg_EEwcsNgeeg', '9ugpNKKhnYRa51qXoxUw_A',
#         '7wSnkgOORRCqVDa_n8Upxg', 'vj6AetpADpHOYtMRZsXX3g',
#         'RzgQioExrGZDkY3vNuziOQ'],
#        dtype='object', name='business_id'),
#  '6GXkFJDkdwHKShmo4jYJ1A': Index(['edJoBsse6nsF0BYh6pATAg', 'SZU9c8V2GuREDN5KgyHFJw',
#         '-loV4cB2Uh9TCltTRgGzWQ', 'bXrQejeR66IwebuhxPS7GA',
#         'vgDl4_ZjoLLIU2ZPL83GIg'],
#        dtype='object', name='business_id'),
#  '6HfGx_gVu1IHFnPL66kAOQ': Index(['29t8lDBLiwkEd1HA356dOw', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'rlfWeYI1SLvC8ZKM_OvXWA', 'fApb6LKfOdy5u7MP0hsHKg',
#         'nB0dV8yPv29F3-CFMPG8cw'],
#        dtype='object', name='business_id'),
#  '6JDoqUtuH8fAuZ_8QZZ43A': Index(['P_QAD4_iMgqTaWd5On_n3g', 'BErYojCJSO959vzaz9JclQ',
#         'CHh0ZFrQcsk4boOItr2Zuw', '2RtyOlU9mwyVisvgOECaDA',
#         'eL4lyE7LNoXEMvpcJ8WNVw'],
#        dtype='object', name='business_id'),
#  '6MNBAfmm5OfgJ2NV1d22Lw': Index(['1l4-uhraQzNiRjppKyMUUQ', 'TCWnTa69sJ3vGQsdEe3Esw',
#         'O2lFAWD2WXXx5EKkzPutWQ', 'xkYNvZlraS1JGleICGhE1w',
#         'RRGLss4hhvZZuR0N6GQlSw'],
#        dtype='object', name='business_id'),
#  '6VqEiAXLCBjyNcs5UIvR3A': Index(['9ugpNKKhnYRa51qXoxUw_A', 'B2Mpi0gW4-oFFVKkDpIxvg',
#         'crlk8kaurC4zrPUTt7BevQ', 'lu2UpRHLBZfvLG_caNEHKQ',
#         'nB0dV8yPv29F3-CFMPG8cw'],
#        dtype='object', name='business_id'),
#  '6ZCU5Pn3c5iJ95pZFDs2Ag': Index(['bLnC1_-Kd_Z5qhHNQXCUfQ', 'GtrY5U_M1ac3bYCk0DUeIg',
#         'yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'UFpCraqzFBAhtZqmxmiWsA'],
#        dtype='object', name='business_id'),
#  '6brAMB0Xsc11eNg4P6rCzg': Index(['edJoBsse6nsF0BYh6pATAg', 'CYwC5OjwCN6ib_AQDxi3Ow',
#         'qyXcWGL5-bU_uV2VKxqzTw', '_vLfidpLDYHfZ_KnFZ75Lg',
#         'bLnC1_-Kd_Z5qhHNQXCUfQ'],
#        dtype='object', name='business_id'),
#  '6f1z4HveH_CpZJ151hQBgg': Index(['wxdpQV7CZHn6_DFr-JGUgw', 'LlGIlNJE2Nv_PXkH7l4Wmg',
#         'EtM079Cj7-B3G7jPsGYb_Q', 'E_ac8Q20OJD9L8cafCBKaQ',
#         '0RxU5OglQyPVtLKC1LPgsA'],
#        dtype='object', name='business_id'),
#  '6lV_f6U2xvEadLMfP3khZw': Index(['0iHHsSqphxrBWWecYEJcuQ', 'BaWVwChTW_MqkKru_WZp3g',
#         'XgehM3pBZWuXi45J2dqRJQ', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'izSgTrqebu8bN8ONOCs6cQ'],
#        dtype='object', name='business_id'),
#  '6oacxCF2qqokHd-BxEbi7A': Index(['9ugpNKKhnYRa51qXoxUw_A', 'PNVbv2kyUIHeJTDPis2gRg',
#         'UFpCraqzFBAhtZqmxmiWsA', 'eL4lyE7LNoXEMvpcJ8WNVw',
#         'sBxbAv4TEjGZiLmPlnxrbQ'],
#        dtype='object', name='business_id'),
#  '73JnNCF_vbNCOAX6Jk9WGQ': Index(['0tbscjPg4IzURekIn_CJ1Q', 'dkknmgSHWyVaahT8u4ikZw',
#         'YrNtBUOUOYwmRZ_UVwH8iQ', '6m4A_ciUZn1G302yx1YV1w',
#         'NIQWO-Q_F598XlAvZnFVCA'],
#        dtype='object', name='business_id'),
#  '76DYJ26L0NLGaaSlUPpbzQ': Index(['PNVbv2kyUIHeJTDPis2gRg', 'bPVPZeqMuYtU_yGCb4P-jg',
#         'ju4YP8SLdR_BmWr_-Xh83Q', 'mYofSuxrIrPS2Gjsu-ZI4w',
#         '8MoqZqlNN9AXzG91_Hpc_Q'],
#        dtype='object', name='business_id'),
#  '780PK3f7m8HBKaMSC83Iuw': Index(['Rl42JbSMsmNW3LRjsTMYAg', 'E7RtIisUoRMcADSebBgNAA',
#         'bbEXAEFr4RYHLlZ-HFssTA', 'W7gSJz80DywKnPRIGjA2Bw',
#         'MJI-bNIn3QDgiGggm9Wp1w'],
#        dtype='object', name='business_id'),
#  '79JCGOJwUkD7nKWx8cfGVg': Index(['SZU9c8V2GuREDN5KgyHFJw', 'bbEXAEFr4RYHLlZ-HFssTA',
#         'JSrab1rTrhBq0X80o6fPrQ', '29t8lDBLiwkEd1HA356dOw',
#         'Jj89pTJS8pGE17lY2s6EDQ'],
#        dtype='object', name='business_id'),
#  '7Na1pUcEv3oF_QTRwZ-2iw': Index(['wb9P0ipW4ysbgNA9jIl3bg', 'onLwomlGswMhhmOEAeAVEg',
#         '1kVnChI4aqsPw9i2PVqkkw', '18eWJFJbXyR9j_5xfcRLYA',
#         '7kc2qp0PINf5qW8soYREYw'],
#        dtype='object', name='business_id'),
#  '7S2fLCuj9MOGmwSO9SSHlw': Index(['edJoBsse6nsF0BYh6pATAg', 'Js3m_GdqNUGnEgXJ8WMtfQ',
#         'Kthnb7PjDSd7FsBp4wqoHA', 'IRyKDIF51M0GcqS8yfPcYA',
#         '1xsBRB203LiYLcC3mktfdA'],
#        dtype='object', name='business_id'),
#  '7WZ1YuYYW5Ez3yzzulA7Kw': Index(['r2IhvKZQ_wLR5mLBnPOilg', 'h4zjPjFmQgJQzYEXLcHenw',
#         'edJoBsse6nsF0BYh6pATAg', 'BHZZFNH4wu5VAq_JypqjiQ',
#         'v4lz71o76wWD8H15NsbZGA'],
#        dtype='object', name='business_id'),
#  '7gn6q55hkN9_3ATMu8mp2Q': Index(['3VrqxApK-iwfRohlAuIt0g', 'edJoBsse6nsF0BYh6pATAg',
#         'xHG-xznai_fgceFDl6xn5w', 'fVUurZgbWXzp2QzDzJzmpA',
#         'CkENBnSJFfPA1hY0qrqfCg'],
#        dtype='object', name='business_id'),
#  '7lKzYA3pZWxpnTFRNpPCFA': Index(['Rl42JbSMsmNW3LRjsTMYAg', '7wSnkgOORRCqVDa_n8Upxg',
#         'FTFaEinJgzqY0ZHQMUSpQQ', 'eBxc95u_Gcs9bLST0UntOQ',
#         'pqF3WkYktbR28uk2PSR7Rg'],
#        dtype='object', name='business_id'),
#  '7tCjGuRFmNwGZW0jtK37mw': Index(['U3grYFIeu6RgAAQgdriHww', 'WhTRPUduXy3mRBYlmSmsKw',
#         'bPVPZeqMuYtU_yGCb4P-jg', 'NIQWO-Q_F598XlAvZnFVCA',
#         '-SS3ep20HKhuOhzDkkt9aA'],
#        dtype='object', name='business_id'),
#  '7urBCOnYpUbHh-Pt4M0cUQ': Index(['kwqXOtLCbNjgvwuMj4H1AQ', 'KSYONgGtrK0nKXfroB-bwg',
#         'r2IhvKZQ_wLR5mLBnPOilg', '4kfbEcAMepvkjt3H7INYBg',
#         'Qkg16mN-8QR66gjzg6gMyw'],
#        dtype='object', name='business_id'),
#  '80FjagwZJYt1Bvvvl_vqmg': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  '86Oe8OA4QG2bGcsFek_C4A': Index(['wKOD2ZWMpiJcdSswRXVuRA', 'mwsA08gpaEALG3C1ZI4ktw',
#         'GuzbBFraIq-fbkjfvaTRvg', 'Y0izXh4Dv1_YU68tn43Xiw',
#         'I0jFTYVDs-WHwKR2XHQlRA'],
#        dtype='object', name='business_id'),
#  '86WYiv6T14Fbf2x0yGP8jA': Index(['ODvaMIpjD6bHiwQ9-kmECw', 'mwsA08gpaEALG3C1ZI4ktw',
#         'AmAc0eD6lyVyb7QdOAO1Mg', 'zRWhcNF3AVuB3ti7V4t88g',
#         'Un-UDVOuv1co3TMmGaumxA'],
#        dtype='object', name='business_id'),
#  '87X9z9-YFtX58mbQ2L1KPQ': Index(['od_MWVpghkvSsl1HKasM9A', 'thlyktt2c7v1DyOpSVSibw',
#         '29t8lDBLiwkEd1HA356dOw', 'XgehM3pBZWuXi45J2dqRJQ',
#         'U2hkeMI-q4cS35QolJYN0A'],
#        dtype='object', name='business_id'),
#  '8G_G3864kEDCNrDQQHIpkA': Index(['34Eqv8jXgxg_EEwcsNgeeg', 'TVX2a4bVuCE2VUIkiLdZrQ',
#         'uZYBF0YTU_iKq4_L_PDtMQ', 'D_WS8rM-DVygaCKbIErZ6Q',
#         '-kfHz1kimX62QEceFkkB_g'],
#        dtype='object', name='business_id'),
#  '8N6_U0rM2A3h8xgKpXuXig': Index(['NuMR1xJu6Ewxaicc4yLOFw', 'y4x_wAQvUxvTR8iV-JP4Jg',
#         'OzGk7arJv6FPrWqaYSvyKQ', 'Qki5LF9vIN7KPM3gn2WkJQ',
#         'U3grYFIeu6RgAAQgdriHww'],
#        dtype='object', name='business_id'),
#  '8RVDulnqcGPgXPfA0UF7yg': Index(['wupvqueqdEZXQxv14sa9vw', '6EPPtwJR1kdIfHiCjzCzuw',
#         'nYPzsOjvida-ne7swSPHpA', '18eWJFJbXyR9j_5xfcRLYA',
#         '0it-2gWk_gyuZyEMQzBBuQ'],
#        dtype='object', name='business_id'),
#  '8S1rR9_97XhkIRj0Cn7POw': Index(['TVX2a4bVuCE2VUIkiLdZrQ', 'bLnC1_-Kd_Z5qhHNQXCUfQ',
#         'r2IhvKZQ_wLR5mLBnPOilg', 'D_WS8rM-DVygaCKbIErZ6Q',
#         '2RtyOlU9mwyVisvgOECaDA'],
#        dtype='object', name='business_id'),
#  '8_-MLDyHBZ1-XGLrAhlDWg': Index(['B_q2xoAgTyn6U4YNEc3kSw', 'b2Za53CjptGyf9K0fFnrAg',
#         'EZc2myE2mYk2h9JK9qu8gw', 'TCWnTa69sJ3vGQsdEe3Esw',
#         'WhTRPUduXy3mRBYlmSmsKw'],
#        dtype='object', name='business_id'),
#  '8_RAFPhjCh_A1WVDET6ebA': Index(['Ss6f5v_t5Vddiaz4ZOxL0g', 'edJoBsse6nsF0BYh6pATAg',
#         'yPSejq3_erxo9zdVYTBnZA', 'oGDGlUbOjHxmmCh8ZYcDCg',
#         '1rC0hBT49gVljFQYTIGIaA'],
#        dtype='object', name='business_id'),
#  '8drMKNHWavs2g6uf0pLtvg': Index(['l-rGtJt0E7PAklT0IK7oFQ', 'j3Ml_qEFnDOaH5miNzG6xw',
#         'gebiRewfieSdtt17PTW6Zg', 'U3grYFIeu6RgAAQgdriHww',
#         'fqStx0SvwMFChX_HIdUeEQ'],
#        dtype='object', name='business_id'),
#  '8f8VU3RpwRKRowjzk5MtIg': Index(['iHdrLu8deF5GceB0V1rPhA', 'r926yelr_EJAKQCjdD6AWA',
#         'vyOVT4bcW227LRwJGHTeSw', 'T9I4G6Or3sAbyYmB7c23hw',
#         'QLHgjBHBoeIUoEvIPvjHnw'],
#        dtype='object', name='business_id'),
#  '8lZBYTaP5Q5bg_uM3wsn0w': Index(['gjCxTVItFxk46rCZ-YaiFA', 'E7RtIisUoRMcADSebBgNAA',
#         'qyXcWGL5-bU_uV2VKxqzTw', 'nYPzsOjvida-ne7swSPHpA',
#         'r2IhvKZQ_wLR5mLBnPOilg'],
#        dtype='object', name='business_id'),
#  '90LPHMWQTbrurfAs_j4cAw': Index(['LlGIlNJE2Nv_PXkH7l4Wmg', 'Qki5LF9vIN7KPM3gn2WkJQ',
#         '4IqrY1mXK65HgrrgkpE-cw', 'B1yPXzIIJrLWyTcE4jsYuQ',
#         '9xW7LsJpyhVZFRb6z9xorg'],
#        dtype='object', name='business_id'),
#  '91tdXzCCTx9ePbdIgsiyXw': Index(['s4k1P9FHfPUzw3dqXRp7eA', 'DqVpNtgFCP47n6frh-LREA',
#         'PWWGbkPC_agn-4s1Hv1W5A', 'yPSejq3_erxo9zdVYTBnZA',
#         '5Z7HXqp22lSiN0Q8iF94hQ'],
#        dtype='object', name='business_id'),
#  '94cMFXuUjTdaKWnxRJjTkg': Index(['8_r9EZL6vX5fPBoVh3gUrA', 'iBBV8vesQ8fo2IQA7an1JA',
#         'znlrxrY4InSx7ekPZxoHRw', 'q36uZc2hQml10YGHazJaoQ',
#         'vhWlxyLEWAbNOMtQ42yzFg'],
#        dtype='object', name='business_id'),
#  '9MtIvSW2AVAnS6cbYH-HcQ': Index(['qUH2FppY7RL96F5tXzA0hQ', '-kY_HDP7IMvGl-kBIZVU4A',
#         '1rC0hBT49gVljFQYTIGIaA', 'nB0dV8yPv29F3-CFMPG8cw',
#         '-ipZBVF9nWm1vzrvQ3444A'],
#        dtype='object', name='business_id'),
#  '9SwFJsT44ShBbzNPulruCw': Index(['6RBZfirnzE4NahJTn1UPNA', 'SYHDOHRNAH-2xsw3XB5qbg',
#         'PWWGbkPC_agn-4s1Hv1W5A', 'GuzbBFraIq-fbkjfvaTRvg',
#         'TzNk1TcWLZn0JCpO83hBAA'],
#        dtype='object', name='business_id'),
#  '9qxZWyZcgYZJqPTvWoWjBg': Index(['wb9P0ipW4ysbgNA9jIl3bg', 'IZZ7J14VnJGyUqYH1tgT6w',
#         'iMTjejk6apJKzCukZnDw5A', '3KI0WnM1_lnY4QPRtT5O8A',
#         'crlk8kaurC4zrPUTt7BevQ'],
#        dtype='object', name='business_id'),
#  '9uTysypqImdsxJDlBXz_Ag': Index(['54oLdsGU9B8HxFTqCCqV-A', 'f7S0WFDy_J1TGahYhnoMLA',
#         'PaqDZUu76fZtMvcYqCEBig', '4NozMd-0ufrS7sUZ95948w',
#         'oGDGlUbOjHxmmCh8ZYcDCg'],
#        dtype='object', name='business_id'),
#  'A-l-oIHCal0atVXtRsIrzA': Index(['U3grYFIeu6RgAAQgdriHww', 'BErYojCJSO959vzaz9JclQ',
#         '3Wy21heeDm8h2tSZfcj6OA', 'yPSejq3_erxo9zdVYTBnZA',
#         'iBBV8vesQ8fo2IQA7an1JA'],
#        dtype='object', name='business_id'),
#  'A4bsa7ykYRVCnb4h2vZALw': Index(['oGDGlUbOjHxmmCh8ZYcDCg', '-kfHz1kimX62QEceFkkB_g',
#         'IRyKDIF51M0GcqS8yfPcYA', 'i5C6RVgr03HSrgCl8oa1Fg',
#         'OM5beWRkxZSu1TShUC3EDw'],
#        dtype='object', name='business_id'),
#  'A6ETSMBVOiRpHPft8lnK9g': Index(['WUGRmrfSzQCyeG6mYAM-vw', 'skY6r8WAkYqpV7_TxNm23w',
#         'Vt5gk5h5VlHXLu-cVKzOXw', 'edJoBsse6nsF0BYh6pATAg',
#         'EZc2myE2mYk2h9JK9qu8gw'],
#        dtype='object', name='business_id'),
#  'A8hNCkw27N6kxu7EbFdLuw': Index(['r926yelr_EJAKQCjdD6AWA', 'skY6r8WAkYqpV7_TxNm23w',
#         'iBBV8vesQ8fo2IQA7an1JA', 'PPcz-0UtIJ8O7xDT551y2g',
#         '0RxU5OglQyPVtLKC1LPgsA'],
#        dtype='object', name='business_id'),
#  'AH1CstZHr-uvkaKDdF6D0w': Index(['Rl42JbSMsmNW3LRjsTMYAg', '8_r9EZL6vX5fPBoVh3gUrA',
#         'V0SSA36N_FpGaikuo4H7hQ', 'DzpaiMQnB_sNhZPrgdvKHg',
#         'EtM079Cj7-B3G7jPsGYb_Q'],
#        dtype='object', name='business_id'),
#  'AH5WSA0MEm5eGgP3uYDu-g': Index(['f3eve2cxUIzyanWnHdMtFQ', '9ugpNKKhnYRa51qXoxUw_A',
#         'EZc2myE2mYk2h9JK9qu8gw', 'Qkg16mN-8QR66gjzg6gMyw',
#         'PWWGbkPC_agn-4s1Hv1W5A'],
#        dtype='object', name='business_id'),
#  'AQ_rpad7JQREara5O8sitQ': Index(['CoZ2mpsMBP8HUG1ymKoZTg', 'R_8S3Iuhpzoi3nM-xq3kcw',
#         'yEmEDomLUofVtbZoUeFV5g', '5vObJIHLO-QOMrw_MvC4rA',
#         'onLwomlGswMhhmOEAeAVEg'],
#        dtype='object', name='business_id'),
#  'AcHDA-RzJxDW4QcFs_lAqQ': Index(['Rl42JbSMsmNW3LRjsTMYAg', 'm4kvY0viCwxqRtgOycnKVQ',
#         'bXrQejeR66IwebuhxPS7GA', '1rC0hBT49gVljFQYTIGIaA',
#         '-ujBP1Dw0j1-Ffaz97-LXQ'],
#        dtype='object', name='business_id'),
#  'AdOsV-ggJPBpWOni6wcu8g': Index(['LlGIlNJE2Nv_PXkH7l4Wmg', 'L6nIOUwcTGgQKExGHmvTzQ',
#         'Qki5LF9vIN7KPM3gn2WkJQ', 'yM7eA2uuH3Ch7OYVj3PKSw',
#         '2xxkaRy7rP5EUyjFt2J5kA'],
#        dtype='object', name='business_id'),
#  'AekJJM_FaiTL3u5U0RStww': Index(['U2hkeMI-q4cS35QolJYN0A', 'tthy48ZIX_wfY8Dy0Dvg6w',
#         '-FM4CxOg4XXmX_Ebky_SiQ', '_ecVi-tVoaKHKYxNkxFj7w',
#         'z6I4QVP1M1HXETgwD92XHg'],
#        dtype='object', name='business_id'),
#  'AzUi--1McRUYdMg15H05SQ': Index(['0RxU5OglQyPVtLKC1LPgsA', 'k6Ptrc94R-Mk549pDEVTFA',
#         'qM2gfO-cqpDzxmIX-XzuWA', 'IoihJkcF2FcE-sHOneat-A',
#         'JSrab1rTrhBq0X80o6fPrQ'],
#        dtype='object', name='business_id'),
#  'B-IFEFxmq9lT8323UiOqOQ': Index(['uZYBF0YTU_iKq4_L_PDtMQ', 'NmexnuLm3zyKxsgwbCe7ug',
#         'LKM0wL3GMsi8NwEdz-_n8w', 'qUH2FppY7RL96F5tXzA0hQ',
#         'AmAc0eD6lyVyb7QdOAO1Mg'],
#        dtype='object', name='business_id'),
#  'B3xvWa3K-4U42KK5WIN9TQ': Index(['0jpFptAehZhLl3nkhHDanA', 'EXYbKA1tocvOK_1tXxZXLA',
#         'UjgqSqa4Biy34pHSEdwj_g', '5Z7HXqp22lSiN0Q8iF94hQ',
#         'eBxc95u_Gcs9bLST0UntOQ'],
#        dtype='object', name='business_id'),
#  'B5s_DCLVrBLrL8U6TEVlwA': Index(['U2hkeMI-q4cS35QolJYN0A', 'UjgqSqa4Biy34pHSEdwj_g',
#         'b5hxsRw76UUXcotxlCipuQ', 'E_ac8Q20OJD9L8cafCBKaQ',
#         'vhWlxyLEWAbNOMtQ42yzFg'],
#        dtype='object', name='business_id'),
#  'BUl1LqMyWTREp4QTuYb3rQ': Index(['LQo1BT1j1noU4k4ITZhZfg', 'yPSejq3_erxo9zdVYTBnZA',
#         'edJoBsse6nsF0BYh6pATAg', 'V0SSA36N_FpGaikuo4H7hQ',
#         'VAIOtbsxdNmuhUKkQZFRlA'],
#        dtype='object', name='business_id'),
#  'BqcFc5DWEPo-U6_uAY9k3Q': Index(['FH0MVF7kK0D76Hh4e7hXfQ', 'FEBwxZMEpxRwVXx9Fm0XZw',
#         'yEmEDomLUofVtbZoUeFV5g', '-kfHz1kimX62QEceFkkB_g',
#         'yzJQJNDb173Y_wdPCLj5qg'],
#        dtype='object', name='business_id'),
#  'CZUbIc3MDkQykVCxH1BWLg': Index(['8RlO6NuhWzXktp-1croq5A', 'xkYNvZlraS1JGleICGhE1w',
#         'LKM0wL3GMsi8NwEdz-_n8w', 'skY6r8WAkYqpV7_TxNm23w',
#         '1FURjeGJi_LBXcJQg8eskw'],
#        dtype='object', name='business_id'),
#  'Ccb1-pROzPfmXfvC8o2ZRw': Index(['IoihJkcF2FcE-sHOneat-A', 'CkENBnSJFfPA1hY0qrqfCg',
#         'TzNk1TcWLZn0JCpO83hBAA', 'UuRZpgZsHX7PyykHV3wbZg',
#         'FE5R_F7svUphKeUWuxA0JA'],
#        dtype='object', name='business_id'),
#  'Ce9qJVPxwjQxAMgg2NSSKw': Index(['0mUVD5sDXZjd66XwATN8XA', 'L6nIOUwcTGgQKExGHmvTzQ',
#         'Un-UDVOuv1co3TMmGaumxA', 'bbEXAEFr4RYHLlZ-HFssTA',
#         'o4IiNbNybcy-L4vzTSoDJw'],
#        dtype='object', name='business_id'),
#  'Cn22zXTPrJL_F0QhjfXgjw': Index(['SZU9c8V2GuREDN5KgyHFJw', 'FH0MVF7kK0D76Hh4e7hXfQ',
#         'FY_FkUeQxVqAjc9V0IAc2Q', 'C-aATB7SbuwMBPN5dgjghQ',
#         'EZc2myE2mYk2h9JK9qu8gw'],
#        dtype='object', name='business_id'),
#  'D-OhcgclnyDPsk6ueeHgqA': Index(['rPVmM0aJbC6lU_mnDiZ2Rw', 'LlGIlNJE2Nv_PXkH7l4Wmg',
#         'bbEXAEFr4RYHLlZ-HFssTA', '34Eqv8jXgxg_EEwcsNgeeg',
#         'y4x_wAQvUxvTR8iV-JP4Jg'],
#        dtype='object', name='business_id'),
#  'D1UV_yDGLjO-69cV7z2A6w': Index(['r2IhvKZQ_wLR5mLBnPOilg', 'OjHy_M9BrUmdJ4L3KCCCWQ',
#         'eX7o_-s5TmDT-DMfTV4cmw', 'FTFaEinJgzqY0ZHQMUSpQQ',
#         'syuKX2pH3JJhOOppzNI6SA'],
#        dtype='object', name='business_id'),
#  'DAXuBz8W8I0P6Fqden3kjA': Index(['f3eve2cxUIzyanWnHdMtFQ', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'Js3m_GdqNUGnEgXJ8WMtfQ', 'NuMR1xJu6Ewxaicc4yLOFw',
#         'BVzFvRrgMpL62oPIqGvLMg'],
#        dtype='object', name='business_id'),
#  'DE_1gvTvo5jsHU1ZzEGHCA': Index(['U2hkeMI-q4cS35QolJYN0A', 'U3grYFIeu6RgAAQgdriHww',
#         '2xxkaRy7rP5EUyjFt2J5kA', 'OM5beWRkxZSu1TShUC3EDw',
#         'zbrIMldF_O1ZQ0vpUaaa8A'],
#        dtype='object', name='business_id'),
#  'DFV_n-igTwGk48YGngkTLA': Index(['KSYONgGtrK0nKXfroB-bwg', 'bVaRZDHkWdsHuARGxxpREw',
#         '0jpFptAehZhLl3nkhHDanA', 'U2hkeMI-q4cS35QolJYN0A',
#         'yw3vRR7XLIjEnlhMnVzR7w'],
#        dtype='object', name='business_id'),
#  'DMtVkV1K2DPimItj9xUfjw': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'DbFznZYkkz_F6NnWXo0vfA': Index(['06pNHtxgPhGhZpM0Z2uzNw', 'IZJacI6XEUxy3_wbW76Qfw',
#         'TI3Rydw47yBMzY1oW2wJUg', 'bbEXAEFr4RYHLlZ-HFssTA',
#         'G0rJD85hUDQ0Omz0rOFeOQ'],
#        dtype='object', name='business_id'),
#  'Dbjz_pg5DT85blIcmidOow': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'DcXLBKRRxkjM0wDBefgTLg': Index(['mAqgsZBTN-wsShMpkz2o9g', 'e8IBUW8tO5XlmgD4fSMtqA',
#         'FDTwPQ4CNWEOY0rfh4eTzQ', 'LlGIlNJE2Nv_PXkH7l4Wmg',
#         'QaFbv7aLQBcfT4xMF1_WnQ'],
#        dtype='object', name='business_id'),
#  'DeZ_FlVfFEVtjokeW1TNPw': Index(['yPSejq3_erxo9zdVYTBnZA', 'nnn78cplvQGZSMVblpI5gQ',
#         'vj6AetpADpHOYtMRZsXX3g', 'YxWiv24PHCseiVvGlqKFrQ',
#         'KSYONgGtrK0nKXfroB-bwg'],
#        dtype='object', name='business_id'),
#  'Drv3DYJkIG48obos_TkM7Q': Index(['U3grYFIeu6RgAAQgdriHww', '4kfbEcAMepvkjt3H7INYBg',
#         'ZrxlfdFU_qpnIHI2DmoRxA', 'WhTRPUduXy3mRBYlmSmsKw',
#         '06pNHtxgPhGhZpM0Z2uzNw'],
#        dtype='object', name='business_id'),
#  'DtHmukDBlL-e-yAiYV8E4g': Index(['3xJ_6qxRA0sdUm3ThCPiCw', '0it-2gWk_gyuZyEMQzBBuQ',
#         'kdowTW3-5Qcr8je9LgItKQ', 'LlGIlNJE2Nv_PXkH7l4Wmg',
#         '0RxU5OglQyPVtLKC1LPgsA'],
#        dtype='object', name='business_id'),
#  'DvWM62NWf2MV1EpN7T8S1A': Index(['2aP9wvEqpGLLDVpWTWlAog', 'E_ac8Q20OJD9L8cafCBKaQ',
#         '4VW4_ghjdYw0Wl40Voa9cw', '2YnQAJdeFrcgPa8MqIYcDg',
#         'cOoTIQ0RcudE1R5aRVZzdw'],
#        dtype='object', name='business_id'),
#  'E5p6Zo3bgxLepIS0zUuERQ': Index(['yPSejq3_erxo9zdVYTBnZA', 'TVX2a4bVuCE2VUIkiLdZrQ',
#         '0qu0fNTOsSmuREYVIMPuIQ', 'PHSda9zEwtFicCICD6TP1A',
#         'bLnC1_-Kd_Z5qhHNQXCUfQ'],
#        dtype='object', name='business_id'),
#  'ECPPKjNtbmD44aRWXCtDXw': Index(['NIQWO-Q_F598XlAvZnFVCA', 'FpNhzu3w0XgyedhOLDuK8g',
#         'UuRZpgZsHX7PyykHV3wbZg', 'FTFaEinJgzqY0ZHQMUSpQQ',
#         'FAc2Mv92KL00cbLdpAc0kQ'],
#        dtype='object', name='business_id'),
#  'EHFsXudXO2JXVlh8Hd9ovg': Index(['1kVnChI4aqsPw9i2PVqkkw', 'wJiaLWAxfqDeFsmE2cI8tg',
#         'XHxAIQR-QAz6j1RMaz_J1A', 'YgbIbmfDlB-bZSsjuIfKwA',
#         '-kY_HDP7IMvGl-kBIZVU4A'],
#        dtype='object', name='business_id'),
#  'EHjp3-183IXI-sC0yluZwg': Index(['KSYONgGtrK0nKXfroB-bwg', 'q-1ICFSqs2MwDGfe5tX-SQ',
#         'r8tU21scBflMxWiBESPtRQ', '-loV4cB2Uh9TCltTRgGzWQ',
#         'CoZ2mpsMBP8HUG1ymKoZTg'],
#        dtype='object', name='business_id'),
#  'ENm-kPLqGvbYIe3PcMSQ9g': Index(['-FM4CxOg4XXmX_Ebky_SiQ', 'YxWiv24PHCseiVvGlqKFrQ',
#         '-TjT3y-Glfnbt6LbKETAYg', 'o4IiNbNybcy-L4vzTSoDJw',
#         '6RBZfirnzE4NahJTn1UPNA'],
#        dtype='object', name='business_id'),
#  'EUrS2Q0M8f2Bc5ZLIRmJaQ': Index(['6RBZfirnzE4NahJTn1UPNA', 'U2hkeMI-q4cS35QolJYN0A',
#         'qdpdUjdkEUpzYDdce2yZng', '4D7QDfPOsSPfKxBi3gs_qQ',
#         'PWWGbkPC_agn-4s1Hv1W5A'],
#        dtype='object', name='business_id'),
#  'EV0JptRgAn0tOntQ_lAxSA': Index(['oinV9xrSkR3b_T8sK1nsqg', '-FM4CxOg4XXmX_Ebky_SiQ',
#         'EXYbKA1tocvOK_1tXxZXLA', 'B1yPXzIIJrLWyTcE4jsYuQ',
#         'eX7o_-s5TmDT-DMfTV4cmw'],
#        dtype='object', name='business_id'),
#  'EsZYgKOkjK-_EgFZqcWZdA': Index(['qyXcWGL5-bU_uV2VKxqzTw', 'wb9P0ipW4ysbgNA9jIl3bg',
#         'pqF3WkYktbR28uk2PSR7Rg', 'OM5beWRkxZSu1TShUC3EDw',
#         'jR3sTUWCPuOCWpdm8Pn-wQ'],
#        dtype='object', name='business_id'),
#  'F9egiLGl16yoQSbmk038pA': Index(['tf6S06LD09IFDHUpOPqPaw', 'vyOVT4bcW227LRwJGHTeSw',
#         'j1yb8y-jFwpG_hW9AH3PrQ', 'WhTRPUduXy3mRBYlmSmsKw',
#         'pKSB4wXLiS8rd1cAEgD8oA'],
#        dtype='object', name='business_id'),
#  'FHjXci4DchP21Y9Tgh4SRQ': Index(['pKSB4wXLiS8rd1cAEgD8oA', 'TVX2a4bVuCE2VUIkiLdZrQ',
#         'GtrY5U_M1ac3bYCk0DUeIg', 'Qkg16mN-8QR66gjzg6gMyw',
#         '6RBZfirnzE4NahJTn1UPNA'],
#        dtype='object', name='business_id'),
#  'FJddyAuOx-sORbFyfSLqkA': Index(['SZU9c8V2GuREDN5KgyHFJw', 'tthy48ZIX_wfY8Dy0Dvg6w',
#         'j_m8zce-jSRQn5JmC633GQ', '2nk4hq2oRfym8ROQ5iS47g',
#         'NIQWO-Q_F598XlAvZnFVCA'],
#        dtype='object', name='business_id'),
#  'FQbd3tj7rluxyoTw-VlPCQ': Index(['uZYBF0YTU_iKq4_L_PDtMQ', '6RBZfirnzE4NahJTn1UPNA',
#         'y4x_wAQvUxvTR8iV-JP4Jg', 'gebiRewfieSdtt17PTW6Zg',
#         '5uNCvNy9L6peKeKP1RRPyg'],
#        dtype='object', name='business_id'),
#  'FxdCb7Dl8c2hYn2t_7qRBA': Index(['JSrab1rTrhBq0X80o6fPrQ', 'VeFfrEZ4iWaecrQg6Eq4cg',
#         'T9I4G6Or3sAbyYmB7c23hw', 'm-EfDi7UBwdiEBm7NXqq3w',
#         'UA3HxLprLSOO9J6l1iR2Cg'],
#        dtype='object', name='business_id'),
#  'GK5_Ad81QASsftZ4JwSs5g': Index(['1FURjeGJi_LBXcJQg8eskw', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'FEBwxZMEpxRwVXx9Fm0XZw', 'Bm-NlFiZWMCwmmz9B_rlCA',
#         'zRWhcNF3AVuB3ti7V4t88g'],
#        dtype='object', name='business_id'),
#  'GRY4NFhvPGUnJx1Nq1ckwQ': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'GTACb4xg72eiMfGmIOZcXQ': Index(['QaFbv7aLQBcfT4xMF1_WnQ', 'PNVbv2kyUIHeJTDPis2gRg',
#         'GtrY5U_M1ac3bYCk0DUeIg', 'vyOVT4bcW227LRwJGHTeSw',
#         '2N9WHETHcYJsfYpHQ-qN_A'],
#        dtype='object', name='business_id'),
#  'GqDuGPjYE1l0e7Arv9EcDQ': Index(['5vObJIHLO-QOMrw_MvC4rA', '4VW4_ghjdYw0Wl40Voa9cw',
#         '1FURjeGJi_LBXcJQg8eskw', 'onLwomlGswMhhmOEAeAVEg',
#         '3xJ_6qxRA0sdUm3ThCPiCw'],
#        dtype='object', name='business_id'),
#  'GxGNAXumenO5lpzjYe3aLQ': Index(['3Wy21heeDm8h2tSZfcj6OA', 'q-1ICFSqs2MwDGfe5tX-SQ',
#         'l-rGtJt0E7PAklT0IK7oFQ', 'D1OT9vuepvXJrn5VDgm4YA',
#         'QFh-h_OZ5Io-mBk32HN28A'],
#        dtype='object', name='business_id'),
#  'H1B3oUh2K1hKWoMX0T_d5A': Index(['0ac5lGA_0wdKDnib3y59Xg', 'PVo1orQ9R7ZHfg90QACh-w',
#         'c-W17u2jiFOD2H_d6uo-bQ', 'SZU9c8V2GuREDN5KgyHFJw',
#         '9h0i4lVC5eCVhRTanWsEAg'],
#        dtype='object', name='business_id'),
#  'H4BQdYjmalz7g0l2BqbMLA': Index(['8MoqZqlNN9AXzG91_Hpc_Q', 'RIXWht1pZG8pe1SJk5hhXw',
#         'q-1ICFSqs2MwDGfe5tX-SQ', 'YXaCcpETNtxrNNK6TbUTlw',
#         'LQo1BT1j1noU4k4ITZhZfg'],
#        dtype='object', name='business_id'),
#  'H7Qcv2zW7-ytEIJMYeR6HA': Index(['f3eve2cxUIzyanWnHdMtFQ', '-FM4CxOg4XXmX_Ebky_SiQ',
#         'nYPzsOjvida-ne7swSPHpA', '2N9WHETHcYJsfYpHQ-qN_A',
#         'q36uZc2hQml10YGHazJaoQ'],
#        dtype='object', name='business_id'),
#  'HHSfDwS1IWufKQZTtmh_hA': Index(['wupvqueqdEZXQxv14sa9vw', 'c0p9TawJSQHchy5aL8NWgQ',
#         'ol6ATB97MdIuhm6yAGOeMQ', 'IDyJPdJ-zTXJ_FSSOMOgbg',
#         '2WHu0k5VVM1Pn9AFzkSBlA'],
#        dtype='object', name='business_id'),
#  'HM9M6ArnI0h5R-cLRKqmRA': Index(['YXKot5TH9MhC4khAn0JC3w', 'sRopdCT6Hf0mwaAHJek7Fw',
#         'TVX2a4bVuCE2VUIkiLdZrQ', 'pWDE_rueENu_f5HKA_AsWw',
#         'b2Za53CjptGyf9K0fFnrAg'],
#        dtype='object', name='business_id'),
#  'HMDIH-YN7nMcH98foV1Ylw': Index(['S8saWaZlToeNoloR2fMrAQ', 'CUWituEeIX3xA0xU7X82Ow',
#         'w79qtK0PpeDWrnY7E-uTRg', 'wxdpQV7CZHn6_DFr-JGUgw',
#         'CoZ2mpsMBP8HUG1ymKoZTg'],
#        dtype='object', name='business_id'),
#  'Hb9bbJmZMyh6liJ8z9Dbcg': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'HcpeRexFBt3phRHqnwBCAA': Index(['CkENBnSJFfPA1hY0qrqfCg', '27zlxlmlQu9KBr5Vj4MGeg',
#         'P_QAD4_iMgqTaWd5On_n3g', '3Wy21heeDm8h2tSZfcj6OA',
#         'zbrIMldF_O1ZQ0vpUaaa8A'],
#        dtype='object', name='business_id'),
#  'HpSJp6pVyzFeYnup3qAXBQ': Index(['znlrxrY4InSx7ekPZxoHRw', 'bVaRZDHkWdsHuARGxxpREw',
#         'HOXbILWYZJkNUYYzYK_tZA', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'thlyktt2c7v1DyOpSVSibw'],
#        dtype='object', name='business_id'),
#  'Hq8g2fou954t4rxBvfEqJg': Index(['edJoBsse6nsF0BYh6pATAg', '6smGb7xv5fDbBsLgW1WC2w',
#         'LQo1BT1j1noU4k4ITZhZfg', 'l-rGtJt0E7PAklT0IK7oFQ',
#         '5vIfUavd23X3lBzjnnc4QA'],
#        dtype='object', name='business_id'),
#  'HsvWhLZLkfXDckYP9UpN4w': Index(['JjmmSW_QQh2Db4fuIEMATA', 'U3grYFIeu6RgAAQgdriHww',
#         'PPcz-0UtIJ8O7xDT551y2g', 'SYHDOHRNAH-2xsw3XB5qbg',
#         'omnCKxL0f_akh0eYeJxjDg'],
#        dtype='object', name='business_id'),
#  'Ht1OROATWNP9u_KyY_Sn3Q': Index(['CUWituEeIX3xA0xU7X82Ow', 'wb6rAxDPWP_5AAl3CKCM1w',
#         'bXrQejeR66IwebuhxPS7GA', 'KSYONgGtrK0nKXfroB-bwg',
#         'nYPzsOjvida-ne7swSPHpA'],
#        dtype='object', name='business_id'),
#  'HvR1LJsLzgA7ygxsJDHdKw': Index(['6RBZfirnzE4NahJTn1UPNA', '8vMULlBjFJyS_836tOKnVQ',
#         'fKrmWy4GFsrgdOYhN9pyZA', 'B_q2xoAgTyn6U4YNEc3kSw',
#         'FDTwPQ4CNWEOY0rfh4eTzQ'],
#        dtype='object', name='business_id'),
#  'I8ve0wPoGJxaQfTfdepKrw': Index(['L6nIOUwcTGgQKExGHmvTzQ', '2MWEEuY3dtD2DNP99sNe_A',
#         'i5C6RVgr03HSrgCl8oa1Fg', 'lu2UpRHLBZfvLG_caNEHKQ',
#         'JSrab1rTrhBq0X80o6fPrQ'],
#        dtype='object', name='business_id'),
#  'I9zFTG0HfowsAaWELgju0w': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'IHalLPBURlCw6mdtmY4VgA': Index(['uGo0TCVNOcDQxMArUU0Jrw', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         'YxWiv24PHCseiVvGlqKFrQ', '2xxkaRy7rP5EUyjFt2J5kA',
#         'PNVbv2kyUIHeJTDPis2gRg'],
#        dtype='object', name='business_id'),
#  'IO-jR0uiTni1qKjaBPxhPg': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'IT1EakcqEi4EwpqHaiOeXw': Index(['18eWJFJbXyR9j_5xfcRLYA', '0it-2gWk_gyuZyEMQzBBuQ',
#         '3xJ_6qxRA0sdUm3ThCPiCw', 'FpNhzu3w0XgyedhOLDuK8g',
#         'tf6S06LD09IFDHUpOPqPaw'],
#        dtype='object', name='business_id'),
#  'IkLdv0dFGfRJrtFVJYJnLg': Index(['1l4-uhraQzNiRjppKyMUUQ', '_ecVi-tVoaKHKYxNkxFj7w',
#         'BVzFvRrgMpL62oPIqGvLMg', 'QLHgjBHBoeIUoEvIPvjHnw',
#         'B3itz3WAJAAzZCFx48NYTw'],
#        dtype='object', name='business_id'),
#  'Inkxry_73bD4V5tnI943qA': Index(['U3grYFIeu6RgAAQgdriHww', 'U2hkeMI-q4cS35QolJYN0A',
#         'QLHgjBHBoeIUoEvIPvjHnw', 'FpNhzu3w0XgyedhOLDuK8g',
#         'thlyktt2c7v1DyOpSVSibw'],
#        dtype='object', name='business_id'),
#  'ItRx5clC7nYRV_XkKiUmOA': Index(['tthy48ZIX_wfY8Dy0Dvg6w', '6RBZfirnzE4NahJTn1UPNA',
#         'Ss6f5v_t5Vddiaz4ZOxL0g', 'E3WUDYEvCVMplIFMgeN1xw',
#         'uZYBF0YTU_iKq4_L_PDtMQ'],
#        dtype='object', name='business_id'),
#  'J7Lcd-G4Un31s3iqtO4CGA': Index(['f3eve2cxUIzyanWnHdMtFQ', 'SYHDOHRNAH-2xsw3XB5qbg',
#         'OjHy_M9BrUmdJ4L3KCCCWQ', 't5igEXKZt4CMtA2FX-GoGA',
#         'U3grYFIeu6RgAAQgdriHww'],
#        dtype='object', name='business_id'),
#  'JJVhvZ9h9AJZDByiSUUXog': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'JPyyz36f5fivxAkvdaoG5g': Index(['skY6r8WAkYqpV7_TxNm23w', 'yPSejq3_erxo9zdVYTBnZA',
#         'dDU-0EW4Asx-RnM-vULFQw', 'p6yHZaiijFq4b4P3sYSRjA',
#         'U3grYFIeu6RgAAQgdriHww'],
#        dtype='object', name='business_id'),
#  'JfmoxgXfQ0Ry0p9BpUeiuw': Index(['onLwomlGswMhhmOEAeAVEg', 'GuzbBFraIq-fbkjfvaTRvg',
#         'nYPzsOjvida-ne7swSPHpA', 'BcUE8GGAvqDPcuoJf-ejSQ',
#         '4NozMd-0ufrS7sUZ95948w'],
#        dtype='object', name='business_id'),
#  'JhlwXIkTyz7jU7Gv_Z9xDw': Index(['SZU9c8V2GuREDN5KgyHFJw', 'eX7o_-s5TmDT-DMfTV4cmw',
#         '1J0NIfmrSuV72KzhmYFxMA', 'DzpaiMQnB_sNhZPrgdvKHg',
#         '6RBZfirnzE4NahJTn1UPNA'],
#        dtype='object', name='business_id'),
#  'K73tPv89_EWRs_oo8HBn7Q': Index(['eX7o_-s5TmDT-DMfTV4cmw', 'WhTRPUduXy3mRBYlmSmsKw',
#         '4D7QDfPOsSPfKxBi3gs_qQ', 'qyXcWGL5-bU_uV2VKxqzTw',
#         '34Eqv8jXgxg_EEwcsNgeeg'],
#        dtype='object', name='business_id'),
#  'KBExKQt3_gpwv9X2gfPjEg': Index(['Rl42JbSMsmNW3LRjsTMYAg', 'SsHMgOW3TT48Z7jeV5beqQ',
#         'EUzWWnvcx1pkkWxk2XV6QA', 'CYwC5OjwCN6ib_AQDxi3Ow',
#         'd-5kMts7CzenaPgDzesQDg'],
#        dtype='object', name='business_id'),
#  'KPnJ6SFLW2qKq6VLGNn2-w': Index(['B_q2xoAgTyn6U4YNEc3kSw', 'uO39--k_hrCFgZh-Bl8m8A',
#         'yPSejq3_erxo9zdVYTBnZA', 'U1Gc3wKN5viu_e68KJVOdQ',
#         'U3grYFIeu6RgAAQgdriHww'],
#        dtype='object', name='business_id'),
#  'KedwZXLfeEull0I1Ww1F6A': Index(['PWWGbkPC_agn-4s1Hv1W5A', 'NIQWO-Q_F598XlAvZnFVCA',
#         'iBBV8vesQ8fo2IQA7an1JA', '-ujBP1Dw0j1-Ffaz97-LXQ',
#         'PNVbv2kyUIHeJTDPis2gRg'],
#        dtype='object', name='business_id'),
#  'Kj8Ql6OWLZAiW5OgFKwLDw': Index(['yPSejq3_erxo9zdVYTBnZA', 'oJwMmSZKJOnMboZ_z67MZw',
#         'edJoBsse6nsF0BYh6pATAg', '7IdIGemGZodDAA_9mJCigA',
#         'PWWGbkPC_agn-4s1Hv1W5A'],
#        dtype='object', name='business_id'),
#  'KjIaeRQA8cVzWR71aHPNZg': Index(['2swMZVA832zkmdPBrddPRQ', '-kfHz1kimX62QEceFkkB_g',
#         'WhTRPUduXy3mRBYlmSmsKw', '_Uyinj5wLMJ7x2cCfHO1Yg',
#         'QFh-h_OZ5Io-mBk32HN28A'],
#        dtype='object', name='business_id'),
#  'KltmAwd9TyvFgYbyrrutrA': Index(['0ac5lGA_0wdKDnib3y59Xg', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'eX7o_-s5TmDT-DMfTV4cmw', '5vObJIHLO-QOMrw_MvC4rA',
#         'v1Uesklh8DpEufYOhTq4iA'],
#        dtype='object', name='business_id'),
#  'KpqzABNihVy5lLtX6PXfEQ': Index(['YxWiv24PHCseiVvGlqKFrQ', '8r_n8JdKQ0gePm2neSkL7A',
#         'NuMR1xJu6Ewxaicc4yLOFw', 'FY_FkUeQxVqAjc9V0IAc2Q',
#         'y4x_wAQvUxvTR8iV-JP4Jg'],
#        dtype='object', name='business_id'),
#  'KvGeegR9uyWmkHc7qrBs2A': Index(['6RBZfirnzE4NahJTn1UPNA', '8_r9EZL6vX5fPBoVh3gUrA',
#         'q-1ICFSqs2MwDGfe5tX-SQ', 'xVtO6a4dqKQQzMXkSPL80A',
#         'GwtVBqKzW9j0zNQ7nYnT5g'],
#        dtype='object', name='business_id'),
#  'KxGeqg5ccByhaZfQRI4Nnw': Index(['znlrxrY4InSx7ekPZxoHRw', 'GuzbBFraIq-fbkjfvaTRvg',
#         'd0E938M2_4kcuULUdnj-Xw', 'A-_GjL5P2ry5OD6WgjhDPA',
#         '4kfbEcAMepvkjt3H7INYBg'],
#        dtype='object', name='business_id'),
#  'L-C9gH_a_SLMoHpHoK1-Aw': Index(['UBK6zb5-XUETfVzYkRTj1Q', 'FH0MVF7kK0D76Hh4e7hXfQ',
#         '0iHHsSqphxrBWWecYEJcuQ', 'bXrQejeR66IwebuhxPS7GA',
#         'vyOVT4bcW227LRwJGHTeSw'],
#        dtype='object', name='business_id'),
#  'L8nb-fqdNyXY70zUi1xETg': Index(['_ecVi-tVoaKHKYxNkxFj7w', 'vhWlxyLEWAbNOMtQ42yzFg',
#         'p2kC-cD22QAQzIGD8ZuqFA', 'iHdrLu8deF5GceB0V1rPhA',
#         'znlrxrY4InSx7ekPZxoHRw'],
#        dtype='object', name='business_id'),
#  'LB5AE_V1A0mG_lvZyn96Jg': Index(['1FURjeGJi_LBXcJQg8eskw', 'GuzbBFraIq-fbkjfvaTRvg',
#         'bPVPZeqMuYtU_yGCb4P-jg', 'l-rGtJt0E7PAklT0IK7oFQ',
#         'LKM0wL3GMsi8NwEdz-_n8w'],
#        dtype='object', name='business_id'),
#  'LD6kMBX7LUEVLYYW9z5vOw': Index(['q36uZc2hQml10YGHazJaoQ', '3Wy21heeDm8h2tSZfcj6OA',
#         '-loV4cB2Uh9TCltTRgGzWQ', 'c-W17u2jiFOD2H_d6uo-bQ',
#         'o4IiNbNybcy-L4vzTSoDJw'],
#        dtype='object', name='business_id'),
#  'LM1Aleq_ozhEslRd2GUGEQ': Index(['M2i4sAuljONUy-BSBonkzg', 'EoLzj1yciIjEZS9ZEJe_kQ',
#         'uO39--k_hrCFgZh-Bl8m8A', 'd0E938M2_4kcuULUdnj-Xw',
#         'Kthnb7PjDSd7FsBp4wqoHA'],
#        dtype='object', name='business_id'),
#  'LbRxyPwuwH8_74XIClfUJQ': Index(['UVFrkmNskSRG4pk186-X0A', '-FM4CxOg4XXmX_Ebky_SiQ',
#         'EZc2myE2mYk2h9JK9qu8gw', 'l_slvEnh4v3W8BXF1gYlcQ',
#         'QLHgjBHBoeIUoEvIPvjHnw'],
#        dtype='object', name='business_id'),
#  'LcBZt_bpU5CqwtDJwB3OCg': Index(['2xxkaRy7rP5EUyjFt2J5kA', 'bLnC1_-Kd_Z5qhHNQXCUfQ',
#         '3Wy21heeDm8h2tSZfcj6OA', 'B2Mpi0gW4-oFFVKkDpIxvg',
#         'SsHMgOW3TT48Z7jeV5beqQ'],
#        dtype='object', name='business_id'),
#  'LcG-WcuV4Ynv08chi1e9_A': Index(['DOfiulOub9hVPBCtiDl9Fw', 'pWDE_rueENu_f5HKA_AsWw',
#         'z5N7vgaNSBpjKT_gbY53sw', 'VOcGcN0bvGU_nzxbJgR5jQ',
#         'zbrIMldF_O1ZQ0vpUaaa8A'],
#        dtype='object', name='business_id'),
#  'LcVWPftC-Rgtx9bQ_bCgDw': Index(['qUH2FppY7RL96F5tXzA0hQ', 'Bm-NlFiZWMCwmmz9B_rlCA',
#         'vyOVT4bcW227LRwJGHTeSw', 'Ifw5wqcChnL4zBigtR7NKA',
#         '-r6nmLB5Vi2TLQCxh0_dtw'],
#        dtype='object', name='business_id'),
#  'LgDaQhkRx7VVe-VUA4uP8Q': Index(['j_m8zce-jSRQn5JmC633GQ', 'gjCxTVItFxk46rCZ-YaiFA',
#         'jnDN1GNUqS1Zo5y8sStmbg', 'bPVPZeqMuYtU_yGCb4P-jg',
#         'OM5beWRkxZSu1TShUC3EDw'],
#        dtype='object', name='business_id'),
#  'LlmyL9U9tErJYGMljC08mA': Index(['8_r9EZL6vX5fPBoVh3gUrA', 'Qki5LF9vIN7KPM3gn2WkJQ',
#         '8MoqZqlNN9AXzG91_Hpc_Q', '-TjT3y-Glfnbt6LbKETAYg',
#         'CUWituEeIX3xA0xU7X82Ow'],
#        dtype='object', name='business_id'),
#  'LsiIlOTD2QYeTDwmsHOnZQ': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'M5CDadStKmQxLJPTBGBf0Q': Index(['PWWGbkPC_agn-4s1Hv1W5A', 'tthy48ZIX_wfY8Dy0Dvg6w',
#         'BwUWmUFKCuJ-nN9vFwMt2Q', 'U3grYFIeu6RgAAQgdriHww',
#         'yPSejq3_erxo9zdVYTBnZA'],
#        dtype='object', name='business_id'),
#  'MCNSEMtULCIMOr_Z84T81Q': Index(['yPSejq3_erxo9zdVYTBnZA', 'U3grYFIeu6RgAAQgdriHww',
#         'skY6r8WAkYqpV7_TxNm23w', 'znlrxrY4InSx7ekPZxoHRw',
#         '3Wy21heeDm8h2tSZfcj6OA'],
#        dtype='object', name='business_id'),
#  'MGIfvuAcgbUtRnhWa_Jm2g': Index(['9u79dIXLQzmt9rnOZEnBaQ', '7wSnkgOORRCqVDa_n8Upxg',
#         'E451ihy72tsLMAxbpPa0WQ', 'vmq2cm0Ayol4toVsL4dZfA',
#         'D_WS8rM-DVygaCKbIErZ6Q'],
#        dtype='object', name='business_id'),
#  'MICO1G49b4kCrKDqOMpsxQ': Index(['PVo1orQ9R7ZHfg90QACh-w', '6RBZfirnzE4NahJTn1UPNA',
#         'ajMHxCdDtGPn7NgfcpsBIg', 'U3grYFIeu6RgAAQgdriHww',
#         'LQo1BT1j1noU4k4ITZhZfg'],
#        dtype='object', name='business_id'),
#  'MJVX82yh27SFQz7eqO8muw': Index(['SsHMgOW3TT48Z7jeV5beqQ', 'fVUurZgbWXzp2QzDzJzmpA',
#         'znlrxrY4InSx7ekPZxoHRw', 'TVX2a4bVuCE2VUIkiLdZrQ',
#         'lZ44dxn1TCzJaVBa8Ze8DQ'],
#        dtype='object', name='business_id'),
#  'M_7XUI5J2dPfwt_trc5CBA': Index(['FTFaEinJgzqY0ZHQMUSpQQ', '1FURjeGJi_LBXcJQg8eskw',
#         'KSYONgGtrK0nKXfroB-bwg', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         'CkENBnSJFfPA1hY0qrqfCg'],
#        dtype='object', name='business_id'),
#  'N1kBTC4fV0DKmlZyEEzFtQ': Index(['1FURjeGJi_LBXcJQg8eskw', '5vObJIHLO-QOMrw_MvC4rA',
#         '0it-2gWk_gyuZyEMQzBBuQ', 'jrSC1bwN2lz9dVBrNTejSg',
#         'vC2qm1y3Au5czBtbhc-DNw'],
#        dtype='object', name='business_id'),
#  'NINZwULaeiAfc1rltTBhug': Index(['-FM4CxOg4XXmX_Ebky_SiQ', 'U3grYFIeu6RgAAQgdriHww',
#         '4D7QDfPOsSPfKxBi3gs_qQ', 'eX7o_-s5TmDT-DMfTV4cmw',
#         '34Eqv8jXgxg_EEwcsNgeeg'],
#        dtype='object', name='business_id'),
#  'NOvbwDPu0FaS1SpkXvHdAQ': Index(['wupvqueqdEZXQxv14sa9vw', '0it-2gWk_gyuZyEMQzBBuQ',
#         'm4kvY0viCwxqRtgOycnKVQ', '7wcHZ80HLJVwUijAH_efJQ',
#         'U3grYFIeu6RgAAQgdriHww'],
#        dtype='object', name='business_id'),
#  'NYceRSdMfT5njLNsFwnoow': Index(['YxWiv24PHCseiVvGlqKFrQ', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'lZ44dxn1TCzJaVBa8Ze8DQ', 'PVo1orQ9R7ZHfg90QACh-w',
#         'L6nIOUwcTGgQKExGHmvTzQ'],
#        dtype='object', name='business_id'),
#  'NrNy_IU5oWe-amTgA1DHUw': Index(['0RxU5OglQyPVtLKC1LPgsA', 'yM7eA2uuH3Ch7OYVj3PKSw',
#         'syuKX2pH3JJhOOppzNI6SA', '0qu0fNTOsSmuREYVIMPuIQ',
#         'iBBV8vesQ8fo2IQA7an1JA'],
#        dtype='object', name='business_id'),
#  'NuEST2287F_qyCQMhVQDtg': Index(['VAIOtbsxdNmuhUKkQZFRlA', '06pNHtxgPhGhZpM0Z2uzNw',
#         'o4IiNbNybcy-L4vzTSoDJw', '1xsBRB203LiYLcC3mktfdA',
#         '8Vo6LN9gqULhXzoxj5k6kQ'],
#        dtype='object', name='business_id'),
#  'O0jyK3THrCwPquNLD20KNg': Index(['L6nIOUwcTGgQKExGHmvTzQ', '12Gc4OFQ-WAW0fAk2hRZuQ',
#         'r2IhvKZQ_wLR5mLBnPOilg', '1J0NIfmrSuV72KzhmYFxMA',
#         'DBtNuEt5U_dXoalpU8rbcQ'],
#        dtype='object', name='business_id'),
#  'O3r4RbnK3dKqWBEQnn9eHg': Index(['q0DRuEAxE5i57xNSTrDP4Q', 'Bm-NlFiZWMCwmmz9B_rlCA',
#         'A263bVzMdU_-TIMhewOrjQ', '_vLfidpLDYHfZ_KnFZ75Lg',
#         '-TjT3y-Glfnbt6LbKETAYg'],
#        dtype='object', name='business_id'),
#  'OBeuL-_9rMx9N6Lvakcf4Q': Index(['5vObJIHLO-QOMrw_MvC4rA', 'krTxH1a9kzWgwvt3PVH8pQ',
#         '4VW4_ghjdYw0Wl40Voa9cw', 'FdoqtMadj4ybDAL7S-yUBQ',
#         '8Vo6LN9gqULhXzoxj5k6kQ'],
#        dtype='object', name='business_id'),
#  'OGPFWcA863I8QLV_ZWqIRA': Index(['iBBV8vesQ8fo2IQA7an1JA', 'iMTjejk6apJKzCukZnDw5A',
#         'YGgGefpPTFhgthvQvMAGoQ', 'CoZ2mpsMBP8HUG1ymKoZTg',
#         'qM2gfO-cqpDzxmIX-XzuWA'],
#        dtype='object', name='business_id'),
#  'OLt1blTifteKTHfhR89bGQ': Index(['qUH2FppY7RL96F5tXzA0hQ', 'E1R-xslwl7XeTN5lQ7mWPg',
#         'BErYojCJSO959vzaz9JclQ', 'Gg2ZHe57Ztuv8JaFj0mNhw',
#         'yPSejq3_erxo9zdVYTBnZA'],
#        dtype='object', name='business_id'),
#  'OQSuVNDxzClNyZ07o9HFHg': Index(['lu2UpRHLBZfvLG_caNEHKQ', 'ycbmvmBYk4w_ZmdrPL0tBQ',
#         '29t8lDBLiwkEd1HA356dOw', 'tthy48ZIX_wfY8Dy0Dvg6w',
#         'f7S0WFDy_J1TGahYhnoMLA'],
#        dtype='object', name='business_id'),
#  'OVLf6NVTi7noMP1qCKr76w': Index(['6RBZfirnzE4NahJTn1UPNA', 'skY6r8WAkYqpV7_TxNm23w',
#         '4D7QDfPOsSPfKxBi3gs_qQ', '27zlxlmlQu9KBr5Vj4MGeg',
#         'Rl42JbSMsmNW3LRjsTMYAg'],
#        dtype='object', name='business_id'),
# ...
#  'sZTxJMS0co1D1k8aZCukBg': Index(['EZc2myE2mYk2h9JK9qu8gw', 'OM5beWRkxZSu1TShUC3EDw',
#         'uZYBF0YTU_iKq4_L_PDtMQ', 'EPkF-beh6gg_s3HtlAdfiw',
#         'wxdpQV7CZHn6_DFr-JGUgw'],
#        dtype='object', name='business_id'),
#  'sZiNtruAl6w1qr1hFzx_-w': Index(['34Eqv8jXgxg_EEwcsNgeeg', 'edJoBsse6nsF0BYh6pATAg',
#         '4D7QDfPOsSPfKxBi3gs_qQ', 'skY6r8WAkYqpV7_TxNm23w',
#         'TzNk1TcWLZn0JCpO83hBAA'],
#        dtype='object', name='business_id'),
#  'st_faQOKk7H2FwFqn0t3Wg': Index(['-FM4CxOg4XXmX_Ebky_SiQ', '27zlxlmlQu9KBr5Vj4MGeg',
#         'A-_GjL5P2ry5OD6WgjhDPA', 'pUVRCYL8rT4I5Ry5FYkRsA',
#         'uO39--k_hrCFgZh-Bl8m8A'],
#        dtype='object', name='business_id'),
#  't2MBvqhOQV3ug8iUFfivCw': Index(['LuPK46HMxRYEVTXVbBCR1g', '4kfbEcAMepvkjt3H7INYBg',
#         'm4kvY0viCwxqRtgOycnKVQ', 'Js3m_GdqNUGnEgXJ8WMtfQ',
#         '0ac5lGA_0wdKDnib3y59Xg'],
#        dtype='object', name='business_id'),
#  't5qZysyGjfeolxOMFpBaqw': Index(['tyt3pz0x3ZB8GXsSx1a9Aw', 'k3lTRgvPvYUI-cX7_TAqNA',
#         'sRopdCT6Hf0mwaAHJek7Fw', 'HOXbILWYZJkNUYYzYK_tZA',
#         'v4lz71o76wWD8H15NsbZGA'],
#        dtype='object', name='business_id'),
#  't6mmKaKsMxaVuC7dfYSkQg': Index(['SYHDOHRNAH-2xsw3XB5qbg', 'edJoBsse6nsF0BYh6pATAg',
#         '2xxkaRy7rP5EUyjFt2J5kA', 'tthy48ZIX_wfY8Dy0Dvg6w',
#         'OM5beWRkxZSu1TShUC3EDw'],
#        dtype='object', name='business_id'),
#  't6oMDTL1KhmVdQz4phXxVA': Index(['8MoqZqlNN9AXzG91_Hpc_Q', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         '1kVnChI4aqsPw9i2PVqkkw', 'vj6AetpADpHOYtMRZsXX3g',
#         's-iUpeKVCuPd5m4OJ3HixQ'],
#        dtype='object', name='business_id'),
#  't9bfJI2zvx-3eFrN2zvQnw': Index(['JjmmSW_QQh2Db4fuIEMATA', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'LuPK46HMxRYEVTXVbBCR1g', 'z6I4QVP1M1HXETgwD92XHg',
#         'CziOtnFSklimJnBgksDDwA'],
#        dtype='object', name='business_id'),
#  'tNDnUX3OjEMUCvvYX_FVHQ': Index(['hVKH5oED9NgGaZeIiF547A', 'SZU9c8V2GuREDN5KgyHFJw',
#         'vyOVT4bcW227LRwJGHTeSw', 'U1Gc3wKN5viu_e68KJVOdQ',
#         'GuzbBFraIq-fbkjfvaTRvg'],
#        dtype='object', name='business_id'),
#  'tQffKBZlKeNx2WfLgeFJkw': Index(['JjmmSW_QQh2Db4fuIEMATA', 'SYHDOHRNAH-2xsw3XB5qbg',
#         'SZU9c8V2GuREDN5KgyHFJw', 'vhWlxyLEWAbNOMtQ42yzFg',
#         'tf6S06LD09IFDHUpOPqPaw'],
#        dtype='object', name='business_id'),
#  'tbI8YO0O51Mrm_yIiD9Ptw': Index(['skY6r8WAkYqpV7_TxNm23w', '9ugpNKKhnYRa51qXoxUw_A',
#         '6HTGlttrzCMsuGBHO1ZGiw', 'KSYONgGtrK0nKXfroB-bwg',
#         'VAIOtbsxdNmuhUKkQZFRlA'],
#        dtype='object', name='business_id'),
#  'tgTt8j-UCJyJxvK58yDA-g': Index(['0qu0fNTOsSmuREYVIMPuIQ', '29t8lDBLiwkEd1HA356dOw',
#         'vj6AetpADpHOYtMRZsXX3g', 'skY6r8WAkYqpV7_TxNm23w',
#         '1FURjeGJi_LBXcJQg8eskw'],
#        dtype='object', name='business_id'),
#  'tjXzOcnP_HpYUTDOH4mybg': Index(['vj6AetpADpHOYtMRZsXX3g', 'ejqpFQ0dwO7AZhxTO9fySg',
#         'yPSejq3_erxo9zdVYTBnZA', 'sjNVeNqhDjEFHoOybnt2ug',
#         'NDwoKO79_T49UEKVDlHd3A'],
#        dtype='object', name='business_id'),
#  'tsuKfuHyl4cPtD90oHGlug': Index(['Qkg16mN-8QR66gjzg6gMyw', 'ODvaMIpjD6bHiwQ9-kmECw',
#         '54oLdsGU9B8HxFTqCCqV-A', 'VgAKmXE8B7J0I_O_R13UKQ',
#         'vZG0BDPGDJxMGiXcGoVU6w'],
#        dtype='object', name='business_id'),
#  'u2f9VdUmklzXT4m6ZAeqnA': Index(['3fpAmsSuEFNF29UUPpgwlw', 'm4kvY0viCwxqRtgOycnKVQ',
#         '1rC0hBT49gVljFQYTIGIaA', 'vj6AetpADpHOYtMRZsXX3g',
#         'WhTRPUduXy3mRBYlmSmsKw'],
#        dtype='object', name='business_id'),
#  'uBW16OCkFKvzdezUKZFuUQ': Index(['aFhPwy7OhyKah4cJY2QdEQ', 'CoZ2mpsMBP8HUG1ymKoZTg',
#         'E_ac8Q20OJD9L8cafCBKaQ', 'XyYsl2OyoMi6OMvzsdcVoQ',
#         'r2IhvKZQ_wLR5mLBnPOilg'],
#        dtype='object', name='business_id'),
#  'uG6qidYu8pWMrRoB80tbFg': Index(['Ss6f5v_t5Vddiaz4ZOxL0g', '_nSL2u-ZzX6kkAF2D2EZgQ',
#         'r926yelr_EJAKQCjdD6AWA', 'VAIOtbsxdNmuhUKkQZFRlA',
#         'uZYBF0YTU_iKq4_L_PDtMQ'],
#        dtype='object', name='business_id'),
#  'uIRi2CQ69hg0QDGkr-ViQg': Index(['LuPK46HMxRYEVTXVbBCR1g', 'GuzbBFraIq-fbkjfvaTRvg',
#         'MbzgGsMQpGyVrUJXi_Jw0Q', '-H-fZonTLitwHFY_PLAIjA',
#         '2nk4hq2oRfym8ROQ5iS47g'],
#        dtype='object', name='business_id'),
#  'uO9zNgo0Cml4wQptXYkVpQ': Index(['5vObJIHLO-QOMrw_MvC4rA', 'MX2YGruhd0sMNHZGK7p5-Q',
#         'WhTRPUduXy3mRBYlmSmsKw', 'aY_n9RSaD2Yw09jSFFePew',
#         'PNVbv2kyUIHeJTDPis2gRg'],
#        dtype='object', name='business_id'),
#  'uYavT1pzUTCQclDWWNO3kg': Index(['E1R-xslwl7XeTN5lQ7mWPg', 'znlrxrY4InSx7ekPZxoHRw',
#         'skY6r8WAkYqpV7_TxNm23w', 'D1OT9vuepvXJrn5VDgm4YA',
#         'bSfDI69RkUrodsA1QwgnOg'],
#        dtype='object', name='business_id'),
#  'v4OxZjxIpmC6_6x4SvaRPg': Index(['GuzbBFraIq-fbkjfvaTRvg', 'HOXbILWYZJkNUYYzYK_tZA',
#         'fqStx0SvwMFChX_HIdUeEQ', 'U3grYFIeu6RgAAQgdriHww',
#         'AV3XPH1iv8PKSO6mrnYgLg'],
#        dtype='object', name='business_id'),
#  'vOBGQyBHVrlZg1a6ILi23Q': Index(['vyyr3G874jpRYSQo2KPZow', 'IDyJPdJ-zTXJ_FSSOMOgbg',
#         'UuRZpgZsHX7PyykHV3wbZg', 'qUH2FppY7RL96F5tXzA0hQ',
#         'CkENBnSJFfPA1hY0qrqfCg'],
#        dtype='object', name='business_id'),
#  'vSaPxmnyq8X5Ai5e0n4kew': Index(['gjCxTVItFxk46rCZ-YaiFA', 'iMTjejk6apJKzCukZnDw5A',
#         'Qkg16mN-8QR66gjzg6gMyw', 'BEzvmorW8ILha6tcSxBBwA',
#         'edJoBsse6nsF0BYh6pATAg'],
#        dtype='object', name='business_id'),
#  'vT9BgtQEjlypFSOwApe7ng': Index(['f3eve2cxUIzyanWnHdMtFQ', 'ZRy4atrG3YHdb__qtE0FsA',
#         'RRGLss4hhvZZuR0N6GQlSw', 'mxZMSFUamk7SIf5ndCLAxA',
#         'eL4lyE7LNoXEMvpcJ8WNVw'],
#        dtype='object', name='business_id'),
#  'vUiMSePeP9Bf3DvOKqjlbw': Index(['8A5LSwsKK5vXDH1M3_Tf1w', 'yPSejq3_erxo9zdVYTBnZA',
#         'mwsA08gpaEALG3C1ZI4ktw', 'Slg6Ec2D7vEBRmgVUfwkzQ',
#         'BVzFvRrgMpL62oPIqGvLMg'],
#        dtype='object', name='business_id'),
#  'vdioUea83QYfcVpet3PELw': Index(['i5C6RVgr03HSrgCl8oa1Fg', '9ugpNKKhnYRa51qXoxUw_A',
#         '7IdIGemGZodDAA_9mJCigA', '5Z7HXqp22lSiN0Q8iF94hQ',
#         'jtgBkAQuchDYgkdsebzLsQ'],
#        dtype='object', name='business_id'),
#  'vhuFqI2XVGWPPF9PA-Hd5w': Index(['GtrY5U_M1ac3bYCk0DUeIg', 'U3grYFIeu6RgAAQgdriHww',
#         'L6nIOUwcTGgQKExGHmvTzQ', 'vhWlxyLEWAbNOMtQ42yzFg',
#         'FEBwxZMEpxRwVXx9Fm0XZw'],
#        dtype='object', name='business_id'),
#  'vi6XhIthVQzv2_zB4E3QYw': Index(['8Vo6LN9gqULhXzoxj5k6kQ', 'mYofSuxrIrPS2Gjsu-ZI4w',
#         'YXaCcpETNtxrNNK6TbUTlw', 'sxuv5uZU15UHGT_HB1xYxQ',
#         'Nbht3URjeV94507do0goEw'],
#        dtype='object', name='business_id'),
#  'w7KJpRbt5dvxGrptIrsc_Q': Index(['uZYBF0YTU_iKq4_L_PDtMQ', 'skY6r8WAkYqpV7_TxNm23w',
#         'thlyktt2c7v1DyOpSVSibw', '3xJ_6qxRA0sdUm3ThCPiCw',
#         '1FURjeGJi_LBXcJQg8eskw'],
#        dtype='object', name='business_id'),
#  'w8PUgwr4uj020gJIbwbF8w': Index(['CkENBnSJFfPA1hY0qrqfCg', 'xRapA2lG7mjJ6eOqHmxe-A',
#         'CUWituEeIX3xA0xU7X82Ow', 'bXrQejeR66IwebuhxPS7GA',
#         'yM7eA2uuH3Ch7OYVj3PKSw'],
#        dtype='object', name='business_id'),
#  'wVhd99Kl7mIxVMQ_8L210g': Index(['sjNVeNqhDjEFHoOybnt2ug', '5RsVAkDnMrcSbErS6P1eew',
#         'uZYBF0YTU_iKq4_L_PDtMQ', 'skY6r8WAkYqpV7_TxNm23w',
#         'wKOD2ZWMpiJcdSswRXVuRA'],
#        dtype='object', name='business_id'),
#  'wXndNZ8X_gpktERMVgztMQ': Index(['znlrxrY4InSx7ekPZxoHRw', 'vmq2cm0Ayol4toVsL4dZfA',
#         'TUtf4FLtotdQDleYpRIfnw', 'EPkF-beh6gg_s3HtlAdfiw',
#         'bbEXAEFr4RYHLlZ-HFssTA'],
#        dtype='object', name='business_id'),
#  'w_L_pYt3830sy_zWJwjORQ': Index(['T9I4G6Or3sAbyYmB7c23hw', 'Qkg16mN-8QR66gjzg6gMyw',
#         'bPVPZeqMuYtU_yGCb4P-jg', 'yPSejq3_erxo9zdVYTBnZA',
#         'qVitsouI4aBiYx1_Fjn0Pg'],
#        dtype='object', name='business_id'),
#  'wekw0bbIv8o61WkTg7GPkg': Index(['5RsVAkDnMrcSbErS6P1eew', 'Rl42JbSMsmNW3LRjsTMYAg',
#         'SsHMgOW3TT48Z7jeV5beqQ', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         '9ugpNKKhnYRa51qXoxUw_A'],
#        dtype='object', name='business_id'),
#  'wocdHbgYu0zTgECrxi_QVA': Index(['8Vo6LN9gqULhXzoxj5k6kQ', 'WhTRPUduXy3mRBYlmSmsKw',
#         'e-iakFOQCVEEr0-ygBKPog', 'bXrQejeR66IwebuhxPS7GA',
#         'q-1ICFSqs2MwDGfe5tX-SQ'],
#        dtype='object', name='business_id'),
#  'x1jrH3svxjC-6RN1Tnh5lg': Index(['tthy48ZIX_wfY8Dy0Dvg6w', '8Vo6LN9gqULhXzoxj5k6kQ',
#         '0jpFptAehZhLl3nkhHDanA', 'thlyktt2c7v1DyOpSVSibw',
#         'nYPzsOjvida-ne7swSPHpA'],
#        dtype='object', name='business_id'),
#  'x7CGazGfox5noT2zvmWzUg': Index(['8Vo6LN9gqULhXzoxj5k6kQ', 'yPSejq3_erxo9zdVYTBnZA',
#         'VqcHpG3ODZ4KHBhbxcL4-Q', 'sc-MRSa8K0BTE5m3tmgrQw',
#         'AgVekFXqwt4Y1HxfQcpyiw'],
#        dtype='object', name='business_id'),
#  'x8-1qoDJ6X2IoI6CiV41kw': Index(['IZJacI6XEUxy3_wbW76Qfw', '8Vo6LN9gqULhXzoxj5k6kQ',
#         'iHdrLu8deF5GceB0V1rPhA', 'jZncFsMQdrq268OHq_Q6uw',
#         'rlh6-MqKplp6DE42aRuS6w'],
#        dtype='object', name='business_id'),
#  'x8csvp0iaqq_KN7fo2mR_A': Index(['JSrab1rTrhBq0X80o6fPrQ', 'FEBwxZMEpxRwVXx9Fm0XZw',
#         '-nwNPb3G-0L95igrhkvMtw', 'U3grYFIeu6RgAAQgdriHww',
#         'QFh-h_OZ5Io-mBk32HN28A'],
#        dtype='object', name='business_id'),
#  'xE_MPHz7BVm63gbSIgeqKw': Index(['yPSejq3_erxo9zdVYTBnZA', '2RtyOlU9mwyVisvgOECaDA',
#         '3Wy21heeDm8h2tSZfcj6OA', 'CYwC5OjwCN6ib_AQDxi3Ow',
#         '29t8lDBLiwkEd1HA356dOw'],
#        dtype='object', name='business_id'),
#  'xRG5L9jaA916n_ceAKYCpw': Index(['WhTRPUduXy3mRBYlmSmsKw', 'U3grYFIeu6RgAAQgdriHww',
#         'vj6AetpADpHOYtMRZsXX3g', 'znlrxrY4InSx7ekPZxoHRw',
#         'qyXcWGL5-bU_uV2VKxqzTw'],
#        dtype='object', name='business_id'),
#  'xW5NqjYNIqSwcAMNyNUX2A': Index(['znlrxrY4InSx7ekPZxoHRw', 'skY6r8WAkYqpV7_TxNm23w',
#         'thlyktt2c7v1DyOpSVSibw', 'qVitsouI4aBiYx1_Fjn0Pg',
#         'syuKX2pH3JJhOOppzNI6SA'],
#        dtype='object', name='business_id'),
#  'xXjvpYieSuajuc8TpEwktw': Index(['skY6r8WAkYqpV7_TxNm23w', '6RBZfirnzE4NahJTn1UPNA',
#         'kwqXOtLCbNjgvwuMj4H1AQ', 'znlrxrY4InSx7ekPZxoHRw',
#         'bp482wqF6v80AltDNlPDfw'],
#        dtype='object', name='business_id'),
#  'xkNKx0QrJfArnpowF3yHpg': Index(['aOLFlIQibMg_lT2X4qKM2g', 'edJoBsse6nsF0BYh6pATAg',
#         'f3eve2cxUIzyanWnHdMtFQ', '6EizP0XyqITuGZ8GZMI9Lw',
#         'bbEXAEFr4RYHLlZ-HFssTA'],
#        dtype='object', name='business_id'),
#  'xrDkmNTEKn9b-T9st9a93w': Index(['SYHDOHRNAH-2xsw3XB5qbg', 'CoZ2mpsMBP8HUG1ymKoZTg',
#         'JjmmSW_QQh2Db4fuIEMATA', 'O2lFAWD2WXXx5EKkzPutWQ',
#         'G9rBwcWp56C8r6ZFwVuimA'],
#        dtype='object', name='business_id'),
#  'y2sVri1mwawzVbDVogrVZw': Index(['U3grYFIeu6RgAAQgdriHww', '34Eqv8jXgxg_EEwcsNgeeg',
#         'HE-9l_2RSingLV2RZItdsA', 'yM7eA2uuH3Ch7OYVj3PKSw',
#         'D1OT9vuepvXJrn5VDgm4YA'],
#        dtype='object', name='business_id'),
#  'y3nInWaBptG5kPLVQY_MRg': Index(['U3grYFIeu6RgAAQgdriHww', 'VOcGcN0bvGU_nzxbJgR5jQ',
#         'ejqpFQ0dwO7AZhxTO9fySg', 'thlyktt2c7v1DyOpSVSibw',
#         '0qu0fNTOsSmuREYVIMPuIQ'],
#        dtype='object', name='business_id'),
#  'y783d3C4Yjm_cGqHvPQnmA': Index(['o4IiNbNybcy-L4vzTSoDJw', 'ju4YP8SLdR_BmWr_-Xh83Q',
#         'FH0MVF7kK0D76Hh4e7hXfQ', 'UA3HxLprLSOO9J6l1iR2Cg',
#         'G9rBwcWp56C8r6ZFwVuimA'],
#        dtype='object', name='business_id'),
#  'yANxzXdYOWLTU42T4o4Xsw': Index(['tthy48ZIX_wfY8Dy0Dvg6w', 'jnDN1GNUqS1Zo5y8sStmbg',
#         'skY6r8WAkYqpV7_TxNm23w', '0tbscjPg4IzURekIn_CJ1Q',
#         'PaqDZUu76fZtMvcYqCEBig'],
#        dtype='object', name='business_id'),
#  'yBW8YsfCCj6SlIbGke0gPg': Index(['E_ac8Q20OJD9L8cafCBKaQ', 'thlyktt2c7v1DyOpSVSibw',
#         'Slg6Ec2D7vEBRmgVUfwkzQ', 'wK2IixmZUOEFGz1QZqR99Q',
#         'PtaFDKkhxSjcXz6dVM0uLw'],
#        dtype='object', name='business_id'),
#  'yPNaLXcrxC8Qo6EY4Pw27g': Index(['CkENBnSJFfPA1hY0qrqfCg', 'h4zjPjFmQgJQzYEXLcHenw',
#         '-loV4cB2Uh9TCltTRgGzWQ', 'iMTjejk6apJKzCukZnDw5A',
#         'znlrxrY4InSx7ekPZxoHRw'],
#        dtype='object', name='business_id'),
#  'yQzwe-X4PrSW6J1lid_2mw': Index(['mEzH6V1ruMHJrgKuLGoi1g', 'iMTjejk6apJKzCukZnDw5A',
#         'WhTRPUduXy3mRBYlmSmsKw', 'GuzbBFraIq-fbkjfvaTRvg',
#         '-kY_HDP7IMvGl-kBIZVU4A'],
#        dtype='object', name='business_id'),
#  'yRR20attVZUMwQ8uU5PvyQ': Index(['tthy48ZIX_wfY8Dy0Dvg6w', 'Y57sylYCgq2VQJuBCnjPfA',
#         '1J0NIfmrSuV72KzhmYFxMA', 'eikRexw04kC6siBDkFnayQ',
#         'S4ujTsHtCOsHKrKkcjY30Q'],
#        dtype='object', name='business_id'),
#  'yV2oIpPaiijeCayjUESp5w': Index(['zbrIMldF_O1ZQ0vpUaaa8A', 'U3grYFIeu6RgAAQgdriHww',
#         'IoihJkcF2FcE-sHOneat-A', 'v1Uesklh8DpEufYOhTq4iA',
#         'sOTBr5NXzRakDMX4XIqUdQ'],
#        dtype='object', name='business_id'),
#  'yfAOrr9lPqA8L7f5Hj7YhA': Index(['hPzPpfSjgQkpWCD7YjcY-A', 'WhTRPUduXy3mRBYlmSmsKw',
#         '_ecVi-tVoaKHKYxNkxFj7w', 'syuKX2pH3JJhOOppzNI6SA',
#         'RKuAfE06rDcetvOTI5MbbA'],
#        dtype='object', name='business_id'),
#  'ygCrT-aWh7HMZY2eiAAPQQ': Index(['rlh6-MqKplp6DE42aRuS6w', 'b2Za53CjptGyf9K0fFnrAg',
#         '2YnQAJdeFrcgPa8MqIYcDg', 'sxuv5uZU15UHGT_HB1xYxQ',
#         'B_q2xoAgTyn6U4YNEc3kSw'],
#        dtype='object', name='business_id'),
#  'ykxYd_rpDeBBc4D3GkCRtA': Index(['Un-UDVOuv1co3TMmGaumxA', '0qu0fNTOsSmuREYVIMPuIQ',
#         'XkmJfBmH-G7eLiq8vJnJRQ', 'y4x_wAQvUxvTR8iV-JP4Jg',
#         '2nk4hq2oRfym8ROQ5iS47g'],
#        dtype='object', name='business_id'),
#  'ym7uUZt8fVCgWgnaf2-4Rg': Index(['hPzPpfSjgQkpWCD7YjcY-A', '0tbscjPg4IzURekIn_CJ1Q',
#         'tf6S06LD09IFDHUpOPqPaw', 'y4x_wAQvUxvTR8iV-JP4Jg',
#         'znlrxrY4InSx7ekPZxoHRw'],
#        dtype='object', name='business_id'),
#  'ymsiWrlWD3WLy2A_fqzv_Q': Index(['RtJC7xavgAxOITQyAlGCbQ', '0RxU5OglQyPVtLKC1LPgsA',
#         '0ac5lGA_0wdKDnib3y59Xg', 'z6I4QVP1M1HXETgwD92XHg',
#         'FH0MVF7kK0D76Hh4e7hXfQ'],
#        dtype='object', name='business_id'),
#  'yqlwIAbnWVoYWYDfcwxipQ': Index(['uZYBF0YTU_iKq4_L_PDtMQ', '2swMZVA832zkmdPBrddPRQ',
#         'CoZ2mpsMBP8HUG1ymKoZTg', '_vLfidpLDYHfZ_KnFZ75Lg',
#         'ju4YP8SLdR_BmWr_-Xh83Q'],
#        dtype='object', name='business_id'),
#  'yr6_LyQOfqNMOyPntBKV2A': Index(['y4x_wAQvUxvTR8iV-JP4Jg', 'WhTRPUduXy3mRBYlmSmsKw',
#         '4kfbEcAMepvkjt3H7INYBg', 'UBK6zb5-XUETfVzYkRTj1Q',
#         'm4kvY0viCwxqRtgOycnKVQ'],
#        dtype='object', name='business_id'),
#  'ysmGZFFmavPKtQiyBKME7g': Index(['yw3vRR7XLIjEnlhMnVzR7w', 'MX2YGruhd0sMNHZGK7p5-Q',
#         'rPVmM0aJbC6lU_mnDiZ2Rw', 'wJiaLWAxfqDeFsmE2cI8tg',
#         'mPKqBWLSD8wxJLJ_4juY2w'],
#        dtype='object', name='business_id'),
#  'z-WasEI3EDKbC69mQTr4oQ': Index(['yPSejq3_erxo9zdVYTBnZA', '4h4Uskb7B8OTI7oDR7wImQ',
#         'SZU9c8V2GuREDN5KgyHFJw', 'E3WUDYEvCVMplIFMgeN1xw',
#         '27zlxlmlQu9KBr5Vj4MGeg'],
#        dtype='object', name='business_id'),
#  'zJIpM80K_6C6XMmgeBjdSg': Index(['thlyktt2c7v1DyOpSVSibw', 'uO39--k_hrCFgZh-Bl8m8A',
#         'PWWGbkPC_agn-4s1Hv1W5A', 'SYHDOHRNAH-2xsw3XB5qbg',
#         '4kfbEcAMepvkjt3H7INYBg'],
#        dtype='object', name='business_id'),
#  'zN8p_ET3HwlMTuZyHs6NlA': Index(['oGDGlUbOjHxmmCh8ZYcDCg', 'eL4lyE7LNoXEMvpcJ8WNVw',
#         '-FM4CxOg4XXmX_Ebky_SiQ', 'thlyktt2c7v1DyOpSVSibw',
#         '0RxU5OglQyPVtLKC1LPgsA'],
#        dtype='object', name='business_id'),
#  'zPPNyikI-w9w9v66aXIikw': Index(['-FM4CxOg4XXmX_Ebky_SiQ', 'U3grYFIeu6RgAAQgdriHww',
#         '3Wy21heeDm8h2tSZfcj6OA', '23OxrUaCvvVrwSa1z3xG-w',
#         'eBxc95u_Gcs9bLST0UntOQ'],
#        dtype='object', name='business_id'),
#  'zPgwS82fTEoprS1_dzU2eQ': Index(['-M7wzxpUsdSkQd9PDGsJWA', 'bp482wqF6v80AltDNlPDfw',
#         'NTLvzcGNm4IUF_yXIwIhvA', 'sc-MRSa8K0BTE5m3tmgrQw',
#         '4D7QDfPOsSPfKxBi3gs_qQ'],
#        dtype='object', name='business_id'),
#  'zWLhTbc_Q0R2800Q5EPSKw': Index(['yPSejq3_erxo9zdVYTBnZA', '_T8tOBDr3NKNxd0yl5GwjA',
#         'FTFaEinJgzqY0ZHQMUSpQQ', '-TjT3y-Glfnbt6LbKETAYg',
#         'P_QAD4_iMgqTaWd5On_n3g'],
#        dtype='object', name='business_id'),
#  'zWy6PZUpkMldBBKZCBXcDw': Index(['skY6r8WAkYqpV7_TxNm23w', 'uZYBF0YTU_iKq4_L_PDtMQ',
#         'U3grYFIeu6RgAAQgdriHww', 'Ss6f5v_t5Vddiaz4ZOxL0g',
#         'FpNhzu3w0XgyedhOLDuK8g'],
#        dtype='object', name='business_id'),
#  'z_-nrUQ0VzTOa-6LegoODw': Index(['l_slvEnh4v3W8BXF1gYlcQ', 'thlyktt2c7v1DyOpSVSibw',
#         'ycbmvmBYk4w_ZmdrPL0tBQ', '23OxrUaCvvVrwSa1z3xG-w',
#         'lu2UpRHLBZfvLG_caNEHKQ'],
#        dtype='object', name='business_id'),
#  'zoLR8iF92uY1TUt8sGuwkg': Index(['18eWJFJbXyR9j_5xfcRLYA', 'ol6ATB97MdIuhm6yAGOeMQ',
#         '3xJ_6qxRA0sdUm3ThCPiCw', 'kdowTW3-5Qcr8je9LgItKQ',
#         '4VW4_ghjdYw0Wl40Voa9cw'],
#        dtype='object', name='business_id')}

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def calculate_metrics(recommended, actual):
    # Convert to sets for comparison
    recommended_set = set(recommended)
    actual_set = set(actual)

    # Precision: How many of the recommended businesses are relevant?
    true_positives = len(recommended_set & actual_set)
    precision = true_positives / len(recommended_set) if len(recommended_set) > 0 else 0

    # Recall: How many relevant businesses were recommended?
    recall = true_positives / len(actual_set) if len(actual_set) > 0 else 0

    # F1 Score: Harmonic mean of precision and recall
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return precision, recall, f1

# Function to get actual relevant businesses for a user in the test set (rating >= 4)
def get_relevant_businesses(user_id, test_user_item_matrix, threshold=4):
    return test_user_item_matrix.loc[user_id][test_user_item_matrix.loc[user_id] >= threshold].index

# Evaluate precision, recall, and F1 score for each user
precision_list = []
recall_list = []
f1_list = []

for user_id, recs in recommendations.items():
    relevant_businesses = get_relevant_businesses(user_id, test_user_restaurant_matrix)
    
    precision, recall, f1 = calculate_metrics(recs, relevant_businesses)
    
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

# Calculate average precision, recall, and F1 score
average_precision = np.mean(precision_list)
average_recall = np.mean(recall_list)
average_f1 = np.mean(f1_list)

print(f"Average Precision: {average_precision:.4f}")
print(f"Average Recall: {average_recall:.4f}")
print(f"Average F1 Score: {average_f1:.4f}")
# Out:
# Average Precision: 0.0375
# Average Recall: 0.0338
# Average F1 Score: 0.0323

# %% [markdown]
# # metrics for CF using spearman instead

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import spearmanr

# train_user_similarity = cosine_similarity(train_user_restaurant_matrix)

# train_user_similarity_df = pd.DataFrame(train_user_similarity, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

#  between users
train_spearman_corr_matrix = train_user_restaurant_matrix.corr(method='spearman')
train_user_similarity_df = pd.DataFrame(train_spearman_corr_matrix, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

# between restaurants
train_spearman_corr_restaurants = train_user_restaurant_matrix.T.corr(method='spearman')

# %%
#  between users
test_spearman_corr_matrix = train_user_restaurant_matrix.corr(method='spearman')
test_user_similarity_df = pd.DataFrame(test_spearman_corr_matrix, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

# between restaurants
test_spearman_corr_restaurants = train_user_restaurant_matrix.T.corr(method='spearman')

# %%
recommendations = {}
for user_id in test_user_restaurant_matrix.index:
    recs = recommend_businesses(user_id=user_id, user_similarity_df=train_user_similarity_df, user_item_matrix=train_user_restaurant_matrix)
    recommendations[user_id] = recs
# Out:
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user

# %%
# Evaluate precision, recall, and F1 score for each user
precision_list = []
recall_list = []
f1_list = []

for user_id, recs in recommendations.items():
    relevant_businesses = get_relevant_businesses(user_id, test_user_restaurant_matrix)
    
    precision, recall, f1 = calculate_metrics(recs, relevant_businesses)
    
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

# Calculate average precision, recall, and F1 score
average_precision = np.mean(precision_list)
average_recall = np.mean(recall_list)
average_f1 = np.mean(f1_list)

print(f"Average Precision: {average_precision:.4f}")
print(f"Average Recall: {average_recall:.4f}")
print(f"Average F1 Score: {average_f1:.4f}")
# Out:
# Average Precision: 0.0116
# Average Recall: 0.0146
# Average F1 Score: 0.0119

# %% [markdown]
# ## Using pearson instead

# %%
train_pearson_corr_matrix = train_user_restaurant_matrix.corr(method='pearson')
train_user_similarity_df = pd.DataFrame(train_pearson_corr_matrix, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

# between restaurants
# train_spearman_corr_restaurants = train_user_restaurant_matrix.T.corr(method='pearson')

# %%
#  between users
test_pearson_corr_matrix = train_user_restaurant_matrix.corr(method='pearson')
test_user_similarity_df = pd.DataFrame(test_pearson_corr_matrix, index=train_user_restaurant_matrix.index, columns=train_user_restaurant_matrix.index)

# %%
recommendations = {}
for user_id in test_user_restaurant_matrix.index:
    recs = recommend_businesses(user_id=user_id, user_similarity_df=train_user_similarity_df, user_item_matrix=train_user_restaurant_matrix)
    recommendations[user_id] = recs
# Out:
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user
# not enough info for user

# %%
# Evaluate precision, recall, and F1 score for each user
precision_list = []
recall_list = []
f1_list = []

for user_id, recs in recommendations.items():
    relevant_businesses = get_relevant_businesses(user_id, test_user_restaurant_matrix)
    
    precision, recall, f1 = calculate_metrics(recs, relevant_businesses)
    
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

# Calculate average precision, recall, and F1 score
average_precision = np.mean(precision_list)
average_recall = np.mean(recall_list)
average_f1 = np.mean(f1_list)

print(f"Average Precision: {average_precision:.4f}")
print(f"Average Recall: {average_recall:.4f}")
print(f"Average F1 Score: {average_f1:.4f}")
# Out:
# Average Precision: 0.0116
# Average Recall: 0.0146
# Average F1 Score: 0.0119

# %%
# results are exactly the same as spearman... is the correlation matrix wrong? or is it something else.
